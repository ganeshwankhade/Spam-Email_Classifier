# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Data Loading

# %%
data = pd.read_csv('spam.csv', encoding='latin-1')
# Show first 5 in dataset
data.head(5)
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
# Drop some unwanted columns that do not provide insight
data = data.drop(["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis=1)
data = data.rename(columns={"v1":"label", "v2":"text"})
# Show last 5 in dataset
data.tail(5)
# Out:
#      label                                               text
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name

# %%
data["label_tag"] = data.label.map({'ham':0, 'spam':1})
data.head(5)
# Out:
#   label                                               text  label_tag
# 0   ham  Go until jurong point, crazy.. Available only ...          0
# 1   ham                      Ok lar... Joking wif u oni...          0
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...          1
# 3   ham  U dun say so early hor... U c already then say...          0
# 4   ham  Nah I don't think he goes to usf, he lives aro...          0

# %%
# get the size of our dataset
print(data.count())
data.label.value_counts()
# Out:
# label        5572
# text         5572
# label_tag    5572
# dtype: int64
# ham     4825
# spam     747
# Name: label, dtype: int64

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# Training data

# %%
# first 4572/5572 emails
training_data = data[0:4572]
training_data_length = len(training_data.label)
training_data.head()
# Out:
#   label                                               text  label_tag
# 0   ham  Go until jurong point, crazy.. Available only ...          0
# 1   ham                      Ok lar... Joking wif u oni...          0
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...          1
# 3   ham  U dun say so early hor... U c already then say...          0
# 4   ham  Nah I don't think he goes to usf, he lives aro...          0

# %% [markdown]
# Testing data

# %%
# last 1000/5572
test_data = data[-1000:]
test_data_length = len(test_data.label)
test_data.head()
# Out:
#      label                                               text  label_tag
# 4572  spam  \URGENT! This is the 2nd attempt to contact U!...          1
# 4573   ham                           :( but your not here....          0
# 4574   ham     Not directly behind... Abt 4 rows behind Ì_...          0
# 4575  spam  Congratulations ur awarded 500 of CD vouchers ...          1
# 4576  spam  Had your contract mobile 11 Mnths? Latest Moto...          1

# %% [markdown]
# #### What is the shape of our input data

# %% [markdown]
# Training data

# %%
print(training_data.shape)
print(training_data.label.shape)
# Out:
# (4572, 3)
# (4572,)

# %% [markdown]
# There are 3 features and 4572 samples in our trtaining set

# %% [markdown]
# Test data

# %%
print(test_data.shape)
print(test_data.label.shape)
# Out:
# (1000, 3)
# (1000,)

# %% [markdown]
# ### Develop a Predictive Theory

# %%
import random

# %%
def pretty_print_text_and_label(i):
    print(training_data.label[i] + "\t:\t" + training_data.text[i][:80] + "...")

# %%
print("labels \t : \t texts\n")
# choose  a random spam set to analyse
# random.randrange(start, stop, step)
pretty_print_text_and_label(random.randrange(0,4572))
pretty_print_text_and_label(random.randrange(0,4572,4))
pretty_print_text_and_label(random.randrange(0,4572,50))
pretty_print_text_and_label(random.randrange(0,4572,100))
pretty_print_text_and_label(random.randrange(0,4572,200))
pretty_print_text_and_label(random.randrange(0,4572,500))
pretty_print_text_and_label(random.randrange(0,4572,800))
pretty_print_text_and_label(random.randrange(0,4572,1000))
# Out:
# labels 	 : 	 texts
#
# ham	:	K.k:)apo k.good movie....
# ham	:	I'm ok wif it cos i like 2 try new things. But i scared u dun like mah. Cos u sa...
# ham	:	Probably money worries. Things are coming due and i have several outstanding inv...
# ham	:	Wylie update: my weed dealer carlos went to freedom and had a class with lunsfor...
# ham	:	No..but heard abt tat.....
# ham	:	says the  &lt;#&gt;  year old with a man and money. I'm down to my last  &lt;#&g...
# ham	:	He's just gonna worry for nothing. And he won't give you money its no use....
# ham	:	He's just gonna worry for nothing. And he won't give you money its no use....

# %% [markdown]
# It is very easy to distinguish a spam text from a non-spam text (in this case ham) . Spam text occasionaly contain words like **free**, **sell**, **promotion**, **deal**, **offer**, **discount**, **lucky** e.t.c. This way we can let our network learn some of the words assocaiated with spams and based on such criteria we can classify a text as a spam or not.

# %% [markdown]
# #### Theory Validation

# %%
from collections import Counter
import numpy as np
import pprint

# %%
spam_counts = Counter()
ham_counts = Counter()
total_counts = Counter()
spam_ham_ratios = Counter()

pp = pprint.PrettyPrinter(indent=4)

# %%
for i in range(training_data_length):
    if(training_data.label[i] == 0):
        for word in training_data.text[i].split(" "):
            ham_counts[word] += 1
            total_counts[word] += 1
    else:
        for word in training_data.text[i].split(" "):
            spam_counts[word] += 1
            total_counts[word] += 1

# %%
pp.pprint(spam_counts.most_common()[0:30])
# Out:
# [   ('to', 1758),
#     ('you', 1368),
#     ('I', 1204),
#     ('a', 1094),
#     ('the', 989),
#     ('and', 736),
#     ('in', 652),
#     ('is', 648),
#     ('i', 612),
#     ('u', 567),
#     ('for', 529),
#     ('my', 522),
#     ('', 521),
#     ('of', 498),
#     ('me', 465),
#     ('your', 447),
#     ('on', 410),
#     ('have', 402),
#     ('2', 371),
#     ('that', 358),
#     ('are', 327),
#     ('it', 313),
#     ('or', 304),
#     ('call', 303),
#     ('at', 300),
#     ('be', 299),
#     ('not', 292),
#     ('with', 281),
#     ('get', 270),
#     ('will', 266)]

# %%
for word,count in list(total_counts.most_common()):
    if(count > 100):
        spam_ham_ratio = spam_counts[word] / float(ham_counts[word]+1)
        spam_ham_ratios[word] = spam_ham_ratio

pp.pprint(spam_ham_ratios)
# Out:
# Counter({   'to': 1758.0,
#             'you': 1368.0,
#             'I': 1204.0,
#             'a': 1094.0,
#             'the': 989.0,
#             'and': 736.0,
#             'in': 652.0,
#             'is': 648.0,
#             'i': 612.0,
#             'u': 567.0,
#             'for': 529.0,
#             'my': 522.0,
#             '': 521.0,
#             'of': 498.0,
#             'me': 465.0,
#             'your': 447.0,
#             'on': 410.0,
#             'have': 402.0,
#             '2': 371.0,
#             'that': 358.0,
#             'are': 327.0,
#             'it': 313.0,
#             'or': 304.0,
#             'call': 303.0,
#             'at': 300.0,
#             'be': 299.0,
#             'not': 292.0,
#             'with': 281.0,
#             'get': 270.0,
#             'will': 266.0,
#             'U': 253.0,
#             'so': 239.0,
#             'but': 236.0,
#             'can': 235.0,
#             '&lt;#&gt;': 235.0,
#             'ur': 233.0,
#             "I'm": 228.0,
#             'You': 223.0,
#             'when': 204.0,
#             'just': 204.0,
#             'up': 203.0,
#             'from': 201.0,
#             '.': 197.0,
#             '4': 195.0,
#             'do': 191.0,
#             'go': 189.0,
#             'know': 188.0,
#             'this': 187.0,
#             'if': 187.0,
#             'like': 185.0,
#             'we': 183.0,
#             'all': 179.0,
#             'out': 177.0,
#             'got': 170.0,
#             'am': 165.0,
#             'come': 165.0,
#             'now': 156.0,
#             '?': 156.0,
#             'was': 153.0,
#             'by': 134.0,
#             'send': 130.0,
#             'about': 128.0,
#             'want': 127.0,
#             'time': 124.0,
#             '...': 122.0,
#             'Call': 121.0,
#             'then': 120.0,
#             'going': 120.0,
#             "I'll": 118.0,
#             'what': 118.0,
#             'How': 118.0,
#             'n': 117.0,
#             'only': 115.0,
#             'as': 115.0,
#             'need': 114.0,
#             'text': 112.0,
#             'still': 111.0,
#             'But': 110.0,
#             'No': 107.0,
#             'If': 106.0,
#             'been': 104.0,
#             'our': 104.0,
#             'one': 104.0,
#             'no': 102.0,
#             'there': 101.0,
#             'he': 101.0})

# %% [markdown]
# ### Transform Text into Numbers

# %% [markdown]
# Neural Networks only understand numbers hence we have to find a way to represent our text inputs in a way it can understand

# %%
vocab = set(total_counts.keys())
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 13874

# %% [markdown]
# We can see that from all our dataset, we have a total of **13874** unique words. Use this to build up our vocabulary vector containing columns of all these words.
#
# Because, **13874**, can be a large size in memory (a matrix of size **13874 by 4572**), lets allocate its memory once with default zeros and will only change its contents accordingly later.

# %%
vocab_vector = np.zeros((1, vocab_size))
pp.pprint(vocab_vector.shape)
pp.pprint(vocab_vector)
# Out:
# (1, 13874)
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %% [markdown]
# Now, let's create a dictionary that allows us to look at every word in our vocabulary and map it to the `vocab_vector` column.

# %%
#  Maps a word to its column in the vocab_vector
word_column_dict = {}

for i, word in enumerate(vocab):
    # {key: value} is {word: column}
    word_column_dict[word] = i
    
pp.pprint(word_column_dict)
# Out:
# {   '': 0,
#     '!': 11564,
#     '!!': 11546,
#     '!!!': 9762,
#     '!!!!': 12034,
#     "!!''.": 8649,
#     '!1': 10114,
#     '#': 10692,
#     '#150': 1340,
#     '#5000': 11499,
#     '$': 8049,
#     '$1': 7903,
#     '$2': 2388,
#     '$350': 3954,
#     '$5.00': 3557,
#     '$50': 7240,
#     '$50...': 10123,
#     '$700': 8683,
#     '$900': 5139,
#     '$95/pax,': 4221,
#     '%': 100,
#     '%.': 8176,
#     '%of': 13449,
#     '&': 6536,
#     '&SAM': 11036,
#     '&XXX': 9810,
#     '&amp;': 11065,
#     '&gt;:(': 11325,
#     '&it': 12368,
#     '&lt;#&gt;': 7042,
#     '&lt;)': 12142,
#     '&lt;3': 9555,
#     '&lt;DECIMAL&gt;': 8014,
#     '&lt;EMAIL&gt;': 9052,
#     '&lt;TIME&gt;': 1982,
#     '&lt;URL&gt;': 11930,
#     '&othrs': 6234,
#     "'": 10694,
#     "''": 7206,
#     "''OK'',": 5447,
#     "'An": 8518,
#     "'Comfort'": 9925,
#     "'IF": 12518,
#     "'Luxury'": 11391,
#     "'MARRIED'": 8201,
#     "'Maangalyam": 9297,
#     "'Melle": 2458,
#     "'Need'": 10352,
#     "'SIMPLE'": 10335,
#     "'Uptown": 8406,
#     "'Wnevr": 12230,
#     "'anything'": 11625,
#     "'doctors'": 3731,
#     "'help'": 8770,
#     "'hex'": 8753,
#     "'hw": 2065,
#     "'its": 11636,
#     "'ll": 2877,
#     "'taxless'": 6058,
#     "'terrorist'": 7620,
#     "'til": 4404,
#     "'xam...": 1630,
#     '(100p/SMS)': 6958,
#     '(10p/min)': 9218,
#     '(10p/min).': 2665,
#     '(150p/SMS)': 8245,
#     '(18': 8952,
#     '(18+)': 9287,
#     '(25/F)': 7690,
#     '(25p),': 7747,
#     '(32/F)': 6379,
#     "(Alaipayuthe)'": 11765,
#     '(And': 2405,
#     '(Bank': 13049,
#     '(Book': 3177,
#     '(I': 3376,
#     '(More': 6382,
#     '(No': 1484,
#     '(Oru': 6873,
#     '(Send': 4294,
#     '(That': 9452,
#     '(Txt': 2084,
#     '(again),': 5784,
#     '(an': 6151,
#     '(but': 12429,
#     '(come': 12376,
#     '(flights': 12291,
#     '(getting': 2280,
#     "(he's": 537,
#     '(kadeem)': 1489,
#     '(marriage)program': 11602,
#     '(mob': 8856,
#     '(not': 12262,
#     '(or': 2950,
#     '(preferably': 1875,
#     '(quizclub': 4603,
#     '(std': 11184,
#     '(to': 6938,
#     '(\x89Û_)': 10461,
#     ')': 8199,
#     '),': 7840,
#     '*': 4753,
#     '*****': 10332,
#     '***********': 12597,
#     '***************': 4838,
#     '*****UP': 9988,
#     '*9': 759,
#     '*BILLING': 10613,
#     '*HAVE': 1720,
#     "*I'm": 1863,
#     '*I*': 197,
#     '*Missing': 8466,
#     '*Number': 8108,
#     '*Sent:Date': 1259,
#     '*Wait,U': 13783,
#     '*a': 13577,
#     '*adoring': 2655,
#     '*covers': 503,
#     '*deep': 5393,
#     '*devouring': 12631,
#     '*exposes': 10299,
#     '*grins*': 13844,
#     '*kiss*': 12897,
#     '*kisses*': 8426,
#     '*laughs*"': 3446,
#     '*loving': 6298,
#     '*passionate': 12427,
#     '*phews*': 1688,
#     '*possessive': 2069,
#     '*pouts*': 13321,
#     '*pushes': 6569,
#     '*sighs*': 10803,
#     '*sips': 8702,
#     '*smacks': 2138,
#     '*smiles*': 1888,
#     '*stomps': 758,
#     '*teasing': 10094,
#     '*turn*': 7331,
#     '*wicked': 5333,
#     '+': 13595,
#     '+123': 6474,
#     '+447797706009': 13277,
#     '+449071512431': 11260,
#     '+CHEER': 644,
#     '+std': 5851,
#     '+å£400': 9313,
#     ',': 10000,
#     ',kerala': 9281,
#     '-': 5036,
#     '-)': 767,
#     '-Message': 2132,
#     '-NO': 40,
#     '-PLS': 9767,
#     '-Shakespeare-': 10819,
#     '-The': 6657,
#     '-apples&pairs&all': 10885,
#     '-msg': 249,
#     '-sub': 13386,
#     '-u': 9064,
#     '-via': 1908,
#     '.': 11801,
#     '..': 8673,
#     '.."': 2024,
#     '...': 5961,
#     '...*grins*...': 552,
#     '...*kiss*': 2402,
#     '....': 5998,
#     '.....': 2640,
#     '.........': 6485,
#     '......forward': 7274,
#     '..?': 583,
#     '..Shiny': 7010,
#     '..it': 12700,
#     '..now': 9908,
#     '..water.?': 13661,
#     '.Call': 5398,
#     '.Please': 8143,
#     '.Terry\\""': 6522,
#     '.after': 11351,
#     '.be': 11016,
#     '.by': 1442,
#     '.dont': 7709,
#     '.irritating': 6504,
#     '.lovable.': 3162,
#     '.nt': 6720,
#     '/': 13704,
#     '/-': 9864,
#     '/7': 945,
#     '/oz,': 11167,
#     '0': 3694,
#     '008704050406': 12951,
#     '0089(my': 7152,
#     '01223585236': 1777,
#     '01223585334': 1463,
#     '0125698789': 13499,
#     '02': 4257,
#     '02/06/03!': 7765,
#     '02/09/03!': 12511,
#     '0207': 2825,
#     '02072069400.': 6120,
#     '02073162414': 1524,
#     '02085076972': 107,
#     '021': 2506,
#     '050703': 8463,
#     '0578': 7664,
#     '06.': 3697,
#     '07/11/04': 7981,
#     '07008009200': 13111,
#     '07046744435': 5859,
#     '07090201529': 5620,
#     '07090298926': 7217,
#     '07123456789': 919,
#     '0721072': 7597,
#     '07732584351': 12890,
#     '07734396839': 10315,
#     '07742676969': 10421,
#     '07753741225': 2830,
#     '0776xxxxxxx': 8007,
#     '07786200117': 7107,
#     '077xxx': 6110,
#     '07801543489': 13293,
#     '07808': 1346,
#     '07815296484': 13278,
#     '07821230901': 2209,
#     '0789xxxxxxx.': 5562,
#     '07946746291/07880867867': 4531,
#     '0796XXXXXX.': 42,
#     '07973788240': 7172,
#     '07XXXXXXXXX': 10994,
#     '07xxxxxxxxx': 4562,
#     '0800': 6411,
#     '08000407165': 8372,
#     '08000776320': 11230,
#     '08000839402': 4108,
#     '08000930705': 10907,
#     '08000930705.': 134,
#     '08000938767': 2202,
#     '08001950382': 2993,
#     '08002888812': 13066,
#     '08002986030': 12318,
#     '08002986906': 11124,
#     '08002988890': 2270,
#     '08006344447': 859,
#     '0808': 12602,
#     '08081263000': 3004,
#     '08081560665': 4048,
#     '0825': 5474,
#     '0844': 1432,
#     '08448714184': 2047,
#     '0845': 8275,
#     '08450542832': 12902,
#     '08452810071': 234,
#     '08452810073': 2758,
#     "08452810075over18's": 7648,
#     '0870': 10630,
#     '0870..k': 438,
#     '08700621170150p': 5213,
#     '08701237397': 7812,
#     '08701417012': 3097,
#     '08701417012150p': 12521,
#     '0870141701216+': 12868,
#     '087016248': 862,
#     '08701752560.': 11517,
#     '087018728737,': 6037,
#     '0870241182716': 12135,
#     '08702490080': 8689,
#     '08702840625': 10005,
#     '08702840625.COMUK.': 661,
#     '08704439680.': 2222,
#     '08704439680Ts&Cs': 12367,
#     '08706091795': 11723,
#     '08706091795.': 6802,
#     '0870737910216yrs': 6403,
#     '08707500020': 6621,
#     '08707509020': 13260,
#     '0870753331018+': 10381,
#     '08707808226.': 3646,
#     '08708034412': 1683,
#     '08708800282': 1226,
#     '08709222922.': 10120,
#     '08709501522': 12779,
#     '0871-4719-523': 11168,
#     '0871-872-9755': 270,
#     '087104711148': 10199,
#     '08712101358': 7007,
#     '08712103738': 7699,
#     '0871212025016': 4944,
#     '08712300220': 6233,
#     '087123002209am-7pm.': 11101,
#     '08712317606': 7209,
#     '08712400200.': 10036,
#     '08712400603': 13729,
#     '08712402050': 7592,
#     '08712402578': 10749,
#     '08712402779': 3071,
#     '08712402902': 2894,
#     '08712402972': 1324,
#     '08712404000': 13487,
#     '08712405020.': 12483,
#     '08712405022,': 8085,
#     '08712460324': 10854,
#     '08712460324(nat': 4408,
#     '08712466669': 9062,
#     '0871277810810': 8624,
#     '0871277810910p/min': 10112,
#     '08714342399.2stop': 7335,
#     '087147123779am-7pm.': 12458,
#     '08714712379': 883,
#     '08714712388': 10582,
#     '08714712394': 11796,
#     '08714714011': 11166,
#     '08715203028': 4640,
#     '08715203649': 5500,
#     '08715203677': 795,
#     '08715203694': 801,
#     '08715500022': 3598,
#     '08715705022,': 5044,
#     '08717111821': 1660,
#     '08717168528': 647,
#     '08717205546': 3174,
#     '0871750.77.11!': 11336,
#     '08717890890å£1.50': 11212,
#     '08717895698': 11919,
#     '08717898035.': 10740,
#     '08718711108': 5475,
#     '08718720201': 565,
#     '08718723815.': 12815,
#     '08718725756.': 4250,
#     '087187262701.50gbp/mtmsg18': 2785,
#     '08718726970': 11916,
#     '08718726971': 9492,
#     '08718726978': 8230,
#     '08718727868.': 6076,
#     '08718727870': 11217,
#     '08718727870.': 7918,
#     '08718730555': 4156,
#     '08718730666': 13151,
#     '08718738001': 4825,
#     '08718738034.': 13746,
#     '08719180248': 12400,
#     '08719181259': 11680,
#     '08719181503': 10535,
#     '08719181513.': 917,
#     '08719839835.': 423,
#     '08719899217': 6390,
#     '08719899230': 2248,
#     '09041940223': 2177,
#     '09050000301.': 10591,
#     '09050000460': 2710,
#     '09050000555.': 6995,
#     '09050000878.': 1953,
#     '09050000928.': 9840,
#     '09050001295': 13713,
#     '09050001808': 9420,
#     '09050002311': 10539,
#     '09050003091': 3151,
#     '09050005321.': 11619,
#     '09050090044': 2079,
#     '09050280520,': 1405,
#     '09053750005': 3495,
#     '09056242159': 8207,
#     '09057039994': 4116,
#     '09058091854': 6934,
#     '09058091870': 12011,
#     '09058094454': 3805,
#     '09058094455': 10133,
#     '09058094565': 6488,
#     '09058094594': 5953,
#     '09058094597': 7895,
#     '09058094599': 6261,
#     '09058095107': 8950,
#     '09058095201': 9657,
#     '09058097189': 5018,
#     '09058097218': 98,
#     '09058098002.': 1276,
#     '09058099801': 13682,
#     '09061104276': 3194,
#     '09061104283': 12321,
#     '09061209465': 10416,
#     '09061221061': 866,
#     '09061221066': 12065,
#     '09061701444.': 2362,
#     '09061701461.': 5513,
#     '09061701851.': 6637,
#     '09061701939.': 13042,
#     '09061702893.': 9681,
#     '09061743386': 7344,
#     '09061743806': 8269,
#     '09061743810': 1828,
#     '09061743811': 6662,
#     '09061744553': 12784,
#     '09061749602': 8871,
#     '09061790121': 1214,
#     '09061790125': 2395,
#     '09063440451': 6121,
#     '09063442151': 11857,
#     '09063458130': 10571,
#     '0906346330.': 10013,
#     '09064011000.': 3,
#     '09064012103': 4833,
#     '09064012160.': 409,
#     '09064017305': 8494,
#     '09064018838.': 1641,
#     '09064019014': 11111,
#     '09064019788': 5391,
#     '09065069120': 12736,
#     '09065069154': 12044,
#     '09065171142-stopsms-08': 2448,
#     '09065174042.': 12339,
#     '09065394514': 9229,
#     '09065394973': 12064,
#     '09065989180': 5415,
#     '09065989182': 5287,
#     '09065989182.': 10446,
#     '09066350750': 948,
#     '09066358152': 753,
#     '09066358361': 7163,
#     '09066362206': 13215,
#     '09066362220': 8896,
#     '09066362231': 1706,
#     '09066364311': 2857,
#     '09066364349': 12758,
#     '09066364589': 7287,
#     '09066368327': 11243,
#     '09066368470': 7131,
#     '09066368753': 3500,
#     '09066382422': 3940,
#     '09066612661': 2467,
#     '09066660100': 1282,
#     '09071512433': 8177,
#     '09071517866': 6959,
#     '09090204448': 2152,
#     '09090900040': 1071,
#     '09094100151': 13027,
#     '09094646899': 10256,
#     '09096102316': 13795,
#     '09099725823': 12584,
#     '09099726395': 9027,
#     '09099726429': 2404,
#     '09099726481': 4078,
#     '09099726553': 13806,
#     '09111030116.': 6858,
#     '09111032124': 13421,
#     '09701213186': 11096,
#     '0A$NETWORKS': 7375,
#     '1': 4917,
#     "1's": 5996,
#     '1)': 11767,
#     '1)McFly-All': 10563,
#     '1)Unbreakable,': 10767,
#     '1,2': 12992,
#     '1,His': 1864,
#     '1-Hanuman': 11331,
#     '1-month': 1194,
#     '1-u': 872,
#     '1.': 7164,
#     '1.20': 13257,
#     '1.50': 3806,
#     '1.50p': 763,
#     '1.50p/wk.': 3524,
#     '1.5p/min': 64,
#     '1.childish': 9341,
#     '1/08/03!': 9775,
#     '1/1': 9934,
#     '1/2': 1921,
#     '1/2price': 2793,
#     '1/3.': 1612,
#     '10': 4804,
#     '10,000': 2255,
#     '10..': 8763,
#     '10.1mega': 6394,
#     '10/06/03!': 5050,
#     '100': 488,
#     "100's": 3544,
#     '1000': 4392,
#     "1000's": 4037,
#     '1000s': 13211,
#     '1013': 3486,
#     '1030': 5983,
#     '10:10': 9473,
#     '10:30': 6246,
#     '10K,': 11993,
#     '10am': 9047,
#     '10am-7pm': 9004,
#     '10am-9pm': 7426,
#     '10k': 4982,
#     '10p': 4948,
#     '10p.': 2735,
#     '10p/min': 12401,
#     '10p/min.': 1096,
#     '10ppm.': 7478,
#     '10th': 3434,
#     '11': 4184,
#     '11.48': 4580,
#     '1120': 341,
#     '113,': 2689,
#     '1131': 9355,
#     '114/14': 13091,
#     '116': 3937,
#     '118p/msg': 4412,
#     '11?': 8261,
#     '11mths': 4493,
#     '11mths+?': 7299,
#     '12': 1287,
#     '12,000pes,': 13607,
#     '1205': 9397,
#     '121': 2244,
#     '1225': 12732,
#     '123': 1769,
#     '125gift': 11415,
#     '12Mths': 6468,
#     '12hours': 9635,
#     '12hrs': 268,
#     '12mths': 10189,
#     '1327': 12999,
#     '139,': 3195,
#     '1405,': 8618,
#     '140ppm': 4999,
#     '145': 3241,
#     '146tf150p': 11105,
#     '14thMarch.': 5285,
#     '150': 2406,
#     '150P': 5423,
#     '150PPM': 9832,
#     '150p': 4056,
#     '150p.': 10174,
#     '150p/MTmsg': 8011,
#     '150p/Msg': 3484,
#     '150p/Msg.': 511,
#     '150p/MsgrcvdHG/Suite342/2Lands/Row/W1J6HL': 3746,
#     '150p/Mt': 13591,
#     '150p/Mtmsgrcvd18': 9426,
#     '150p/Mtmsgrcvd18+': 2838,
#     '150p/day,': 7089,
#     '150p/min': 13630,
#     '150p/msg': 7888,
#     '150p/msg,': 9372,
#     '150p/msg.': 4665,
#     '150p/rcvd': 11257,
#     '150p/tone': 2673,
#     '150p/tone.': 5479,
#     '150p/wk': 3039,
#     '150pm': 10948,
#     '150pm.': 8033,
#     '150ppermessSubscription': 4667,
#     '150ppm': 949,
#     '150ppm.': 6526,
#     '150ppmPOBox10183BhamB64XE': 7555,
#     '150ppmsg': 10758,
#     '153': 11575,
#     '16': 1469,
#     '16+': 7483,
#     '16+.': 6092,
#     '16+only': 2969,
#     '16+only!': 12256,
#     '1680,': 674,
#     '169': 2549,
#     '18': 5836,
#     '18+': 6330,
#     '18+6*å£1.50(moreFrmMob.': 6341,
#     '18+only': 11142,
#     '18+only.': 11828,
#     '18/11/04': 6952,
#     '1843.': 12144,
#     '18p/txt': 11497,
#     '18yrs': 4285,
#     '195': 4239,
#     '1956669': 376,
#     '1Apple/Day=No': 476,
#     '1Cup': 3469,
#     '1DA': 4318,
#     '1ER': 12610,
#     '1IM': 13791,
#     '1Lemon/Day=No': 13176,
#     '1Tulsi': 8497,
#     '1Winaweek,': 9547,
#     '1YF': 7667,
#     '1hr': 9162,
#     '1hr.': 3513,
#     '1pm': 8345,
#     '1st': 8066,
#     '1st..."': 291,
#     '1st4Terms': 11058,
#     '1stchoice.co.uk': 3351,
#     '1stone,': 13674,
#     '1x150p/wk': 1538,
#     '1x150p/wk.': 5935,
#     '2': 11034,
#     '2!': 7622,
#     '2%': 9068,
#     '2)': 6478,
#     '2)Untamed,': 11210,
#     '2,': 12016,
#     '2,Police': 8120,
#     '2-4-1': 9662,
#     '2-Bajarangabali': 2003,
#     '2-u': 1510,
#     '2.': 2263,
#     '2.15': 12880,
#     '2.30ish': 13070,
#     '2.IM': 4794,
#     '2.U': 12087,
#     '2.naughty': 12569,
#     '2/2': 8135,
#     '20': 10443,
#     '20%': 12316,
#     '20,000': 8641,
#     '200': 10507,
#     '2000': 3737,
#     '2003': 572,
#     '2004': 6944,
#     '2004,': 5874,
#     '2005.': 415,
#     '2006': 5231,
#     '2007': 405,
#     '20M12AQ.': 5431,
#     '20p': 8419,
#     '20p/min': 2595,
#     '21': 3483,
#     '21/m': 13352,
#     '21870000>Hi': 5541,
#     '21st': 11658,
#     '22': 2337,
#     '220-CM2': 11994,
#     '2309.': 2608,
#     '24': 2615,
#     '24/10/04': 6516,
#     '24/7MP': 11535,
#     '24Hrs': 10842,
#     '24M': 12148,
#     '24hrs.': 13353,
#     '24th': 8394,
#     '25': 2925,
#     '25.': 11059,
#     '250': 11774,
#     '25p': 5161,
#     '26.03.05': 2520,
#     '26th': 637,
#     '27/03': 2126,
#     '27/6/03.': 10402,
#     '28': 9931,
#     '28,': 3409,
#     '28/5': 5612,
#     '2814032': 5083,
#     '28days.': 11839,
#     '28th': 13788,
#     "28thFeb.T&C's": 13706,
#     '29/03/05': 204,
#     '2?': 11204,
#     '2C': 7639,
#     '2EZ': 13174,
#     '2End': 12570,
#     '2GETHA!': 3530,
#     '2KBSubject:': 10610,
#     '2MORO!': 4721,
#     '2MOROW': 5791,
#     '2MORRO': 3843,
#     '2MRW': 4699,
#     '2NITE': 10324,
#     '2NITE-TELL': 1969,
#     '2NITE?': 12424,
#     '2PX': 162,
#     '2StopTx': 8379,
#     '2U': 10430,
#     '2WT': 7928,
#     '2WU.': 166,
#     '2channel': 10405,
#     '2day': 6947,
#     '2day!': 6306,
#     '2day,': 10167,
#     '2day.love': 6134,
#     '2exit.': 13133,
#     '2geva,': 6592,
#     '2go': 6339,
#     '2go,': 261,
#     '2go.did': 9488,
#     '2gthr': 2468,
#     '2hrs.': 3468,
#     '2marrow': 434,
#     '2moro': 2221,
#     '2morro': 13673,
#     '2morrow': 10699,
#     '2mro': 1179,
#     '2mrw': 4376,
#     '2nd': 1778,
#     '2nhite': 11152,
#     '2nights': 1824,
#     '2nite': 975,
#     '2nite!.': 2767,
#     '2nite?': 1808,
#     '2optout': 898,
#     '2optout/D3WV': 12033,
#     '2rcv': 7243,
#     '2stop': 821,
#     '2stoptxt': 13129,
#     '2u': 10113,
#     '2waxsto': 4977,
#     '2wks': 6423,
#     '2wks.': 8172,
#     '2years': 6779,
#     '2yr': 2653,
#     '3': 10409,
#     '3!': 9805,
#     '3)': 9214,
#     '3)Cover': 6282,
#     '3)Unkempt.': 3389,
#     '3,': 1557,
#     '3,Wife:': 9138,
#     '3-Maruti': 13099,
#     '3-u': 4206,
#     '3.': 4801,
#     '3.Sentiment': 9,
#     '3.U': 4343,
#     '30': 7944,
#     '300': 4205,
#     '300%': 1227,
#     '300603': 10442,
#     '300p': 180,
#     '300p.': 6603,
#     '3030': 6664,
#     '3030.': 7363,
#     '30Apr': 5314,
#     '30pp/txt': 4681,
#     '30th': 13690,
#     '31': 11603,
#     '31/10/04': 13782,
#     '3100': 12304,
#     '310303.': 577,
#     '31p.msg@150p': 7072,
#     '3230': 3810,
#     '32323.': 2203,
#     '326': 6510,
#     '330.': 5504,
#     '3510i': 10363,
#     '35p.': 9694,
#     '3650': 736,
#     '36504': 2136,
#     '3680': 7204,
#     '3680.Offer': 6385,
#     '373': 2154,
#     '3750': 1398,
#     '391784.': 12848,
#     '3AJ': 7487,
#     '3D!!B)': 6859,
#     '3G': 12355,
#     '3GBP': 12451,
#     '3Lions': 13465,
#     '3POUND': 748,
#     '3SS.': 4590,
#     '3UZ': 12858,
#     '3UZ.': 1926,
#     '3d': 7678,
#     '3days': 4383,
#     '3g': 4935,
#     '3lp': 5313,
#     '3miles': 4797,
#     '3mins': 10967,
#     '3optical': 11123,
#     '3qxj9': 9157,
#     '3rd': 12416,
#     '3rd?': 10706,
#     '3xå£150pw': 5074,
#     '4': 7908,
#     "4'o": 4428,
#     '4)Press': 4645,
#     '4*': 10010,
#     '4*Lux': 13773,
#     '4-6...': 11752,
#     '4-Pavanaputra': 10432,
#     '4-some1': 10466,
#     '4.': 7003,
#     '4...': 11005,
#     '4.15': 3638,
#     '4.47per': 9331,
#     '4.49/month': 4039,
#     '4.50.': 13535,
#     '4.Cook:': 2807,
#     '4.rowdy': 6373,
#     '40': 6305,
#     '400': 12893,
#     '400mins...Call': 6739,
#     '4041': 11645,
#     '40533': 13861,
#     '40GB': 8403,
#     '40mph.': 1123,
#     '41685': 2271,
#     '41782': 1947,
#     '420': 5786,
#     '4217': 8862,
#     '42478': 6695,
#     '430': 5484,
#     '434': 11409,
#     '44': 6200,
#     '4403LDNW1A7RW18': 5151,
#     '447801259231': 8219,
#     '448712404000>Please': 3659,
#     '449050000301': 13570,
#     '450p': 12637,
#     '45239': 9371,
#     '47': 13209,
#     '4742': 7140,
#     '4882': 13691,
#     '4?': 7090,
#     '4GET': 6299,
#     '4JX': 13461,
#     '4T&Ctxt': 4504,
#     '4U': 13846,
#     '4U!:': 9853,
#     '4WARD': 7079,
#     '4a': 10731,
#     '4d': 11673,
#     '4few': 2381,
#     '4fil': 9095,
#     '4get': 10455,
#     '4give': 12906,
#     '4got,': 5145,
#     '4goten': 13684,
#     '4info': 8769,
#     '4mths': 5736,
#     '4th': 10815,
#     '4the': 3775,
#     '4txt/120p': 6466,
#     '4txt/Ì¼1.20': 8815,
#     '4u': 12112,
#     '4u,': 12557,
#     '4u.i': 10914,
#     '4uTxt': 589,
#     '4w': 7044,
#     '4wrd': 7290,
#     '5': 63,
#     '5)': 7602,
#     '5)Gently': 7643,
#     '5+-': 1210,
#     '5+3+2=': 126,
#     '5-Sankatmochan': 5340,
#     '5.': 2904,
#     '5..': 6031,
#     '5.15pm': 6429,
#     '5.30': 6186,
#     '5.Gardener:': 3808,
#     '5.ful': 2276,
#     '5/9/03': 7112,
#     '50': 5590,
#     '50%': 13280,
#     '500': 7827,
#     '505060': 1752,
#     '50p': 9346,
#     '50s?': 11937,
#     '515': 12062,
#     '5226': 5889,
#     '526,': 5570,
#     '528': 9763,
#     '530': 451,
#     '54': 10314,
#     '542': 1546,
#     '545': 8631,
#     '5K,': 12218,
#     '5WB': 2874,
#     '5WE': 10422,
#     '5WQ': 1951,
#     '5digital': 2531,
#     '5free.': 1229,
#     '5ish.': 5290,
#     '5min': 12172,
#     '5pm': 545,
#     '5pm.': 6507,
#     '5th': 3561,
#     '5we.': 2623,
#     '5wkg': 1221,
#     '5years': 6428,
#     '6': 10543,
#     '6,': 9392,
#     '6-Ramaduth': 10958,
#     '6.': 10267,
#     '6...': 4410,
#     '6.30': 8807,
#     '6.45pm.': 1100,
#     '6.House-Maid:': 12158,
#     '6.romantic': 12096,
#     '60,400thousad.i': 11445,
#     '600': 1530,
#     '6031': 10746,
#     '60P': 1554,
#     '60p/min.': 11313,
#     '61200': 6119,
#     '61610': 3661,
#     '62220Cncl': 408,
#     '6230': 3617,
#     '62468': 1370,
#     '630': 12834,
#     '63miles.': 12071,
#     '645': 9665,
#     '650.': 2304,
#     '6669': 11939,
#     '67441233': 4225,
#     '68866.': 3533,
#     '69101.': 12608,
#     '69200': 4885,
#     '69669': 8623,
#     '69669.': 9687,
#     '69696': 11907,
#     '69698': 13024,
#     '69855,': 86,
#     '69866.18': 8063,
#     '69876.': 2711,
#     '69888': 11173,
#     '69888!': 11533,
#     '69888Nyt.': 12609,
#     '69911(å£1.50p.': 539,
#     '69969': 12741,
#     '69988': 8700,
#     '6HL': 7346,
#     '6WU': 1856,
#     '6ZF': 9890,
#     '6days,': 11374,
#     '6hrs': 4459,
#     '6hrs.': 2266,
#     '6ish.': 7288,
#     '6missed': 9721,
#     '6months': 890,
#     '6pm.': 7587,
#     '6pm..:-)': 3156,
#     '6th': 12203,
#     '7': 4324,
#     '7+2+5=?????': 8052,
#     '7,': 11469,
#     '7-Mahaveer': 1952,
#     '7.': 2119,
#     '7.30': 9711,
#     '7.30ish?': 1196,
#     '7.30pm': 653,
#     '7.8p/min': 4190,
#     '7.Children:': 8595,
#     '7.shy': 12818,
#     '7250': 13096,
#     '7250i.': 5551,
#     '730.': 9204,
#     '731': 477,
#     '74355': 8799,
#     '750': 4643,
#     '7548': 10372,
#     '7732584351,': 9593,
#     '786': 2938,
#     '7876150ppm': 1569,
#     '7WS.': 2605,
#     '7am': 5212,
#     '7cfca1a': 11129,
#     '7ish,': 7715,
#     '7ish?': 5595,
#     '7oz.': 10117,
#     '7pm': 6681,
#     '7th': 12292,
#     '8': 6821,
#     "8'o": 4638,
#     '8+6+3=': 11869,
#     '8-8:30': 4319,
#     '8.': 10250,
#     '8.30': 2494,
#     '8.30.': 11758,
#     '8.Attractive': 10124,
#     '8.Neighbour:': 895,
#     "80's": 5813,
#     '800': 13830,
#     '8000930705': 3677,
#     '80062': 3822,
#     '80062.': 9578,
#     '8007': 5611,
#     '80082': 6056,
#     '80086': 5685,
#     '80122300p/wk': 12886,
#     '80155,': 7080,
#     '80160': 5575,
#     '80182': 26,
#     '8027': 5377,
#     '80488': 12692,
#     '80488.': 5837,
#     '80488.biz': 7033,
#     '80608.': 8562,
#     '8077': 4860,
#     '80878.': 3482,
#     '81010': 10178,
#     '81151': 5105,
#     '81303': 95,
#     '81303.': 10562,
#     '81618,': 8471,
#     '81618-?3': 2006,
#     '82242': 522,
#     '82277.': 4904,
#     '82277.unsub': 13313,
#     '82324.': 11664,
#     '82468': 6729,
#     '83021.': 9856,
#     '83049.': 3393,
#     '83110': 7983,
#     '83222': 12392,
#     '83222.': 961,
#     '83332.Please': 514,
#     '83355': 11352,
#     '83355!': 13370,
#     '83370.': 9647,
#     '83383': 3424,
#     '83383.': 6506,
#     '83435.': 2713,
#     '83600': 12993,
#     '83600.': 929,
#     '83738.': 10771,
#     '84,': 12713,
#     '84025': 12319,
#     '84122': 6077,
#     '84128': 4157,
#     '84199': 6316,
#     '84199.': 5782,
#     '84484': 8608,
#     '85': 2143,
#     '85.': 7350,
#     '850.': 4016,
#     '85023': 10878,
#     '85069': 7257,
#     '85222': 6597,
#     '85233': 6868,
#     '8552': 10514,
#     '8552.': 11226,
#     '85555': 4049,
#     '86021': 8600,
#     '861': 4602,
#     '86688': 3632,
#     '87021.': 2462,
#     '87066': 11605,
#     '87070.': 10824,
#     '87077': 8075,
#     '87077:': 6955,
#     '87121': 12440,
#     '87131': 7813,
#     '87131.': 2540,
#     '8714714': 1501,
#     '87239': 6216,
#     '87575.': 5258,
#     '88039': 10527,
#     '88039.SkilGme.TsCs087147403231Winawk!Age16+å£1.50perWKsub': 7104,
#     '88066': 11361,
#     '88088': 2002,
#     '88222': 10669,
#     '88600': 3005,
#     '88600.': 3898,
#     '88800': 4076,
#     '8883': 10450,
#     '88877': 4983,
#     '88877>FREE': 12655,
#     '88888.': 10986,
#     '89034': 8444,
#     '89070': 7273,
#     '89080': 7294,
#     '89105.': 4477,
#     '89123"': 8930,
#     '89545': 6389,
#     '89555': 11088,
#     '89555.': 1288,
#     '89693': 12242,
#     '89693.': 12186,
#     '89938': 4717,
#     '8WP': 5561,
#     '8am': 7418,
#     '8am.': 11486,
#     '8lb': 780,
#     '8pm,': 5845,
#     '8pm.': 2456,
#     '8th': 7902,
#     '8th)': 12240,
#     '8th?': 4041,
#     '9': 746,
#     '9+2+4=': 3912,
#     '9,': 2734,
#     '9.': 8480,
#     '9.funny': 3359,
#     '9061100010': 4719,
#     '9153.': 5129,
#     '930': 2153,
#     '930.': 7143,
#     '945+': 4947,
#     '946': 4629,
#     '97N7QP,': 9219,
#     '98321561': 12188,
#     '9996.': 319,
#     '9?': 13423,
#     '9AE': 11802,
#     '9YT': 1768,
#     '9am': 3396,
#     '9am-11pm': 8813,
#     '9ja': 9761,
#     '9ja.': 8188,
#     '9pm.': 12938,
#     '9t:)': 3230,
#     '9t;-)': 13474,
#     '9th': 8490,
#     ':': 12501,
#     ':(': 3141,
#     ':)': 8045,
#     ':)"': 9228,
#     ':)all': 10793,
#     ':)finally': 570,
#     ':)going': 2580,
#     ':)it': 3572,
#     ':)my': 8115,
#     ':)so': 6787,
#     ':)voice': 8912,
#     ':)why': 5642,
#     ':-(': 1780,
#     ':-)': 1507,
#     ':-):-)': 8460,
#     ':-):-)."': 4455,
#     ':-)only': 6071,
#     ':-)please': 11702,
#     ':-/': 10026,
#     ':-D': 10895,
#     ':-P': 10488,
#     ':/': 8830,
#     ':V': 2973,
#     ':getzed.co.uk': 9587,
#     ':zed': 3906,
#     ';)': 7386,
#     ';).': 11574,
#     ';-(': 1419,
#     ';-)': 7190,
#     ';_;': 2309,
#     ';abel': 11747,
#     '<Forwarded': 5096,
#     '<UKP>2000': 1437,
#     '=': 991,
#     '=)': 7601,
#     '=/': 13137,
#     '=D': 9474,
#     '?': 1208,
#     '?!': 1922,
#     '?!\\"': 2496,
#     '?-': 5716,
#     '?.': 5215,
#     '?1,000': 1708,
#     '?2,000': 13733,
#     '?350': 11227,
#     '??': 9927,
#     '@': 9645,
#     '@Shesil': 464,
#     'A': 2820,
#     'A,': 5680,
#     'A-Green': 1291,
#     'A-ffectionate.': 1628,
#     'A.': 1770,
#     'A21.': 2106,
#     'ABOUT': 7718,
#     'ABOUTAS': 4842,
#     'ABTA': 2210,
#     'ACCEPT': 10531,
#     'ACL03530150PM': 5411,
#     'ACTION': 138,
#     'AD': 7975,
#     'ADAM': 389,
#     'ADDAMSFA,': 13141,
#     'AFEW': 3113,
#     'AFTER': 987,
#     'AFTERNOON?': 8368,
#     'AG': 13336,
#     'AGAIN': 1590,
#     'AGAIN!': 7403,
#     'AGAIN.call': 8221,
#     'AGAINST': 248,
#     'AGE': 10598,
#     'AGE,': 11343,
#     'AGES..RING': 2906,
#     'AGO.': 284,
#     'AGO.CUSOON': 6191,
#     'AIG': 4516,
#     'AINT': 592,
#     'AL!!!!!!!!!': 507,
#     'ALERT!': 7950,
#     'ALEX': 13254,
#     'ALL': 8795,
#     'ALRITE': 1884,
#     'ALSO': 11019,
#     'ALWAYS': 3017,
#     'AM': 2365,
#     'AM!?!': 10104,
#     'AM.': 6843,
#     'AMY': 560,
#     'AN': 7717,
#     'ANAL': 3914,
#     'AND': 1904,
#     'ANNIE': 7640,
#     'ANS': 336,
#     'ANSWER': 549,
#     'ANTELOPE': 2343,
#     'ANYTHING': 9848,
#     'AOM': 6321,
#     'AOM,': 5820,
#     'APRIL.': 13438,
#     'ARE': 12360,
#     'AREA.': 9837,
#     'ARIES': 10251,
#     'AROUND!': 10884,
#     'ARR': 392,
#     'AS': 10283,
#     'ASAP': 3676,
#     'ASAP!': 8648,
#     'ASKED,': 10667,
#     'ASTHERE': 9210,
#     'ASUSUAL!1': 9382,
#     'AT': 6970,
#     'AUCTION': 8438,
#     'AUGUST!': 4578,
#     'AV': 5111,
#     'AVA': 12477,
#     'AVE': 6670,
#     'AVENT': 9504,
#     'AWAITING': 9675,
#     'AWARD!': 6241,
#     'AXIS': 7534,
#     'Aah!': 905,
#     'Aah.': 1101,
#     'Aaniye': 6326,
#     'Aaooooright': 3948,
#     'Ab..,': 5778,
#     'Abbey!': 3567,
#     'Abeg,': 6911,
#     'Aberdeen,': 10161,
#     'Abiola': 2941,
#     'Abiola.': 3460,
#     'About': 8566,
#     'Accept': 1080,
#     'Accident': 3187,
#     'Account': 7156,
#     'Accounts': 10788,
#     'Ache': 9061,
#     'Acnt.': 11584,
#     'Aco&Entry41': 13714,
#     'Activate': 3084,
#     'Active': 13551,
#     'Actually': 1364,
#     'Actually,': 3031,
#     'Address': 12069,
#     'Admirer': 2129,
#     'Adrian': 6209,
#     'Adult': 11326,
#     'Aeronautics': 3793,
#     'Affections...&amp;': 633,
#     'Aft': 3691,
#     'After': 10917,
#     'AfterNoon.': 11905,
#     'Afternoons,': 8220,
#     'Aftr': 8712,
#     'Again': 3764,
#     'Agalla': 9209,
#     'Age': 1190,
#     'Ages': 3109,
#     'Ah': 6475,
#     'Ah,': 2990,
#     'Ahhh.': 10906,
#     'Ahmad': 659,
#     'Aight': 3756,
#     'Aight,': 1449,
#     'Air': 2063,
#     'Airtel': 5633,
#     'Aiya': 4320,
#     'Aiyah': 2235,
#     'Aiyar': 2078,
#     'Aiyo': 2787,
#     'Aiyo...': 5637,
#     'Aka': 9590,
#     'Al': 9038,
#     'Aldrine,': 10944,
#     'AlertFrom:': 3246,
#     'Alex': 176,
#     'Alfie': 8125,
#     'Algarve': 5557,
#     'All': 11671,
#     'Allah,meet': 7122,
#     'Allah.Rakhesh,': 3551,
#     'Allo!': 8264,
#     'Almost': 9803,
#     'Already': 7948,
#     'Alright': 3782,
#     'Alright,': 9401,
#     'Alright.': 9335,
#     'Alrite': 8797,
#     'Also': 13568,
#     'Although': 2740,
#     'Always': 5885,
#     'Alwys': 2413,
#     'Am': 10183,
#     'Amanda': 4553,
#     'Amazing': 1166,
#     'Ambrith..madurai..met': 4484,
#     'American': 12797,
#     'Ami': 2449,
#     'Amrca': 480,
#     'Amrita': 1033,
#     'An': 9296,
#     'And': 4233,
#     'Annoying': 5495,
#     'Another': 4845,
#     'Any': 13401,
#     'Anyone': 4510,
#     'Anything': 1713,
#     'Anything!': 2528,
#     'Anything...': 1656,
#     'Anytime': 12480,
#     'Anytime.': 13559,
#     'Anyway': 724,
#     'Anyway,': 12640,
#     'Anyways': 3419,
#     'Apart': 295,
#     'Apnt': 1716,
#     'Apparently': 9152,
#     'Apply': 8473,
#     'Apps': 9480,
#     'Appt': 9402,
#     'Ar.Praveesh.': 12723,
#     'Arabian': 8823,
#     'Arcade': 2294,
#     'Ard': 11585,
#     'Are': 5193,
#     'Argh': 875,
#     'Argument': 13770,
#     'Arms': 6976,
#     'Arngd': 2370,
#     'Arrow': 3091,
#     'Arul.': 11437,
#     'Arun': 10621,
#     'As': 4687,
#     'Ask': 4960,
#     'Asking': 13619,
#     'At': 2669,
#     'Athletic': 4033,
#     'Atlanta.': 12150,
#     'Atlast': 8434,
#     'Atleast': 1773,
#     'Auction': 5881,
#     'Audrey': 13715,
#     'Audrie': 3645,
#     'August': 11147,
#     'August.': 834,
#     'Auntie': 13232,
#     'Available': 11724,
#     'Ave': 13792,
#     'Avenge': 9998,
#     'Awarded': 12509,
#     'Awesome': 12222,
#     'Awesome,': 1838,
#     'Aww': 7491,
#     'Awww': 3888,
#     'Ay': 6750,
#     'Aå£1.50': 11312,
#     'B': 2651,
#     "B'day": 8374,
#     "B'tooth*.": 3769,
#     'B-Blue': 9135,
#     'B-day': 11095,
#     'B.': 13705,
#     'B/Tooth': 115,
#     'B4': 8737,
#     'B4U': 7126,
#     'BA128NNFWFLY150ppm': 5726,
#     'BABE': 11731,
#     'BABE!': 8013,
#     'BABE,': 11287,
#     'BABE..': 7207,
#     'BABE.SOZI': 2346,
#     'BABES': 12411,
#     'BABY!HOPE': 48,
#     'BACK': 4292,
#     'BACKWARDS)': 2080,
#     'BAHAMAS!': 904,
#     'BAK': 11665,
#     'BAK!': 491,
#     'BANG': 6598,
#     'BANK': 8078,
#     'BANNEDUK': 7472,
#     'BATH.': 9697,
#     'BBC': 9177,
#     'BBD(pooja)': 10347,
#     'BBDELUXE': 11711,
#     'BCK': 433,
#     'BCM1896WC1N3XX': 3526,
#     'BCM4284': 7679,
#     'BCMSFWC1N3XX': 3399,
#     'BCoz,I': 6981,
#     'BE': 8817,
#     'BEAUTIFUL,': 11407,
#     'BED': 4234,
#     'BEDROOM!LOVE': 10882,
#     'BEEN': 4501,
#     'BEFORE': 979,
#     'BEGIN': 8565,
#     'BELIEVE': 27,
#     'BETTER': 1923,
#     'BETTERSN': 5530,
#     'BIDS': 1174,
#     'BIG': 2048,
#     'BIRD': 6464,
#     'BIRTHDAY': 4129,
#     'BIT': 12621,
#     'BLOKE': 10459,
#     'BLOKES': 9430,
#     'BLOOD.Send': 9609,
#     'BMW': 3516,
#     'BONUS': 6426,
#     'BORED': 2750,
#     'BOUT': 9772,
#     'BOUT!)xx': 13613,
#     'BOX': 7447,
#     'BOX139,': 2693,
#     'BOX385': 8140,
#     'BOX420.': 12687,
#     'BOX42WR29C,': 1655,
#     'BOX95QU': 13064,
#     'BOX97N7QP,': 2414,
#     'BOYF?': 11159,
#     'BRAND': 1700,
#     'BREAK': 1497,
#     'BREAKIN': 6229,
#     'BREATHE1': 4980,
#     'BRISTOL': 4153,
#     'BROKE': 8686,
#     'BROTHER': 5017,
#     'BSLVYL': 5843,
#     'BT': 5066,
#     'BT-national': 13430,
#     'BT-national-rate': 10837,
#     'BT-national-rate.': 8266,
#     'BTW': 3602,
#     'BUDDY!!': 5022,
#     'BUT': 10747,
#     'BUTTHERES': 6145,
#     'BY': 9369,
#     'BYATCH': 12664,
#     'Baaaaaaaabe!': 5144,
#     'Baaaaabe!': 12123,
#     'Babe': 11063,
#     'Babe!': 4770,
#     'Babe,': 7327,
#     'Babe:': 11048,
#     'Babe?': 7203,
#     'Baby': 3496,
#     'BabyGoodbye': 5774,
#     'Back': 7828,
#     'Back.': 11733,
#     'Bad': 10899,
#     'Badrith': 6716,
#     'Bahamas': 12823,
#     'Ball': 9560,
#     'Balls.': 10469,
#     'Bam': 11385,
#     'BangBabes': 8606,
#     'Bani': 379,
#     'Bank': 352,
#     'Barbie\\"?': 6874,
#     'Barkleys': 6962,
#     'Barry': 7148,
#     'Bbq': 6433,
#     'Bc': 13205,
#     'Bcm': 12076,
#     'Bcoz': 3618,
#     'Bcoz,': 2093,
#     'Be': 9874,
#     'Bears': 799,
#     'Beautiful': 13555,
#     'Beauty': 6352,
#     'Bec': 2114,
#     'Becaus': 10537,
#     'Because': 3758,
#     'Become': 12457,
#     'Becomes': 221,
#     'Becoz': 4868,
#     'Been': 8331,
#     'Beer': 4003,
#     'Beer-Rs.': 4338,
#     'Beerage?': 10714,
#     'Behind': 13195,
#     'Belovd': 7060,
#     'Ben': 7894,
#     'Best': 5773,
#     'Best1': 7883,
#     'Beth': 2765,
#     'Better': 6473,
#     'Better.': 11156,
#     'Beware': 3717,
#     'Beware!': 1652,
#     'Big,': 1578,
#     'Bill': 11025,
#     'Bill,': 13836,
#     'Bin': 760,
#     'Biola': 11761,
#     'Biro': 3877,
#     'Birthday': 9053,
#     'Birthday?': 5444,
#     'Bishan': 10062,
#     'Bit': 3947,
#     'Bite': 11508,
#     'Bits': 11676,
#     'Black': 9682,
#     "Black;i'm": 4926,
#     'Blank': 11258,
#     'Blank.': 7512,
#     'Bless': 734,
#     'Blind': 6553,
#     'Block': 12981,
#     'Bloody': 13045,
#     'Bloomberg': 11466,
#     'Blu': 12578,
#     'Blue;u': 3184,
#     'Bluetooth': 2059,
#     'Bluetooth!': 2610,
#     'BluetoothHdset': 5,
#     'Bob,': 1491,
#     'Bognor': 3527,
#     'Boltblue': 2756,
#     'Bone': 7357,
#     'Bonus': 3896,
#     'Bonus!': 123,
#     'Boo': 5241,
#     'Boo.': 3100,
#     'Book': 2933,
#     'Booked': 1315,
#     'Bookmark': 3673,
#     'Boooo': 8966,
#     'Bored': 7008,
#     'Boss': 13305,
#     'Both': 4009,
#     'Bought': 9034,
#     'Box': 9163,
#     'Box1146': 13159,
#     'Box177.': 2771,
#     'Box326': 7457,
#     'Box334': 1723,
#     'Box39822': 1418,
#     'Box434SK38WP150PPM18+': 2687,
#     'Box61,M60': 11538,
#     'Boy': 6044,
#     'Boy:': 2934,
#     'Boy;': 6820,
#     'Boys': 10031,
#     'Boys.': 5219,
#     'Brainless': 6165,
#     'Brandy': 8936,
#     'Bray,': 10292,
#     'Brdget': 3034,
#     'Break': 7930,
#     'Breaker': 11255,
#     'Brief': 2335,
#     'Bright': 245,
#     'Brilliant.': 12244,
#     'Bring': 4551,
#     'Bristol': 10875,
#     'British': 11699,
#     'Britney.': 13660,
#     'Broadband': 6845,
#     'Brother': 2591,
#     'Brought': 7911,
#     'Brown;i': 10281,
#     'Bstfrnd': 1456,
#     'Bt': 13571,
#     'Btw': 7225,
#     'Buffy.': 293,
#     'Bugis': 6886,
#     'Building': 7972,
#     'Bull.': 11986,
#     'Burger': 7693,
#     'Burns': 12667,
#     'Busy': 8234,
#     'But': 737,
#     'But,': 4919,
#     'Buy': 13475,
#     'Buzz': 3510,
#     'Buzz!': 6016,
#     'Buzzzz!': 9091,
#     'Bx': 2018,
#     'Bx526,': 3489,
#     'By': 1927,
#     'Bye.': 11866,
#     'C': 8542,
#     'C!': 13233,
#     "C's": 11289,
#     'C)': 4087,
#     'C-IN': 13145,
#     'C-Red': 4609,
#     'C.': 698,
#     'C52.': 7990,
#     'CAL': 6764,
#     'CALL': 5387,
#     'CALLIN': 11672,
#     'CALM': 3970,
#     'CAMERA': 11841,
#     'CAMERA,': 11897,
#     'CAN': 9043,
#     'CANCEL': 7644,
#     'CANT': 8391,
#     'CARD': 6830,
#     'CARE': 7223,
#     'CAREFUL': 5659,
#     'CARLIE': 1308,
#     'CASH': 2564,
#     'CASH!': 3605,
#     'CASH,': 10629,
#     'CAT': 9178,
#     'CATCH': 12998,
#     'CAUSE': 11422,
#     'CC': 5302,
#     'CC:': 4344,
#     'CD': 6172,
#     'CDGT': 13393,
#     'CDs': 4939,
#     'CER': 4700,
#     'CERI': 8722,
#     'CHANCE': 12644,
#     'CHARGE': 10876,
#     'CHARITY': 13622,
#     'CHAT': 7252,
#     'CHECKIN': 9286,
#     'CHEERED': 8748,
#     'CHILLIN': 12855,
#     'CHIT-CHAT': 12576,
#     'CHOSEN': 10425,
#     'CL.': 13166,
#     'CLAIM': 6038,
#     'CLAIRE': 2685,
#     'CLUB': 3521,
#     'CLoSE': 6884,
#     'CM': 6646,
#     'CNN': 9434,
#     'COLLECT': 12909,
#     'COLLEGE': 420,
#     'COLLEGE!': 2473,
#     'COME': 13839,
#     'COMIN': 3570,
#     'COMPLETELY': 2636,
#     'CONCERNED': 5825,
#     'CONTENTION': 12498,
#     'CONTRACT!!': 10213,
#     'CONVINCED': 11853,
#     'COOL...': 10924,
#     'COS': 9785,
#     'COUNTINLOTS': 12005,
#     'CR01327BT': 5877,
#     'CR9': 3675,
#     'CRAZYIN,': 2019,
#     'CREDIT': 13017,
#     'CRISIS!SPK': 12345,
#     'CRO1327': 12814,
#     'CSH11': 11296,
#     'CULDNT': 13600,
#     'CUM': 2055,
#     'CUP': 3743,
#     'CUTE': 11120,
#     'CW25WX': 2627,
#     'CaRE': 13348,
#     'Cab': 12170,
#     'Cable': 8465,
#     'Cali': 864,
#     'Call': 6734,
#     'Call,': 9508,
#     'Call.': 11308,
#     'Call2OptOut/674&': 1155,
#     'CallFREEFONE': 1461,
#     'Caller': 2101,
#     'Callers.': 9246,
#     'Callertune': 10860,
#     'Calls': 4576,
#     'Callså£1/minMobsmore': 4727,
#     'Callså£1/minMobsmoreLKPOBOX177HP51FL': 4663,
#     'Callså£1/minmoremobsEMSPOBox45PO139WA': 5584,
#     'Camcorder': 11423,
#     'Camcorder?': 11348,
#     'Camera': 9029,
#     'Camera!': 10257,
#     'Can': 8040,
#     "Can't": 1785,
#     "Can't.": 12863,
#     'Can.': 13762,
#     'Can...': 5635,
#     'Can?': 3655,
#     'Canada,': 8632,
#     'Canary': 2188,
#     'Cancel': 11759,
#     'Cancer.': 10871,
#     'Cannot': 4331,
#     'Cant': 9695,
#     'Captain': 9638,
#     'Cardiff': 617,
#     'Care..:-)': 11384,
#     'Careful!': 3234,
#     'Carlos': 1091,
#     "Carlos'll": 7878,
#     'Carry': 2643,
#     'Case': 3640,
#     'Cash': 12301,
#     'Cash.': 7355,
#     'Catching': 2377,
#     'Caught': 2952,
#     'Cause': 9842,
#     'Cbe': 8555,
#     'Celebrated': 188,
#     'Celebrations': 2661,
#     'Centre': 6733,
#     'Cha': 9455,
#     'Chachi': 7175,
#     'Chance': 11501,
#     'Chance!': 10969,
#     'Change': 10197,
#     'Channel': 5502,
#     'Charles': 645,
#     'Chart': 8205,
#     'Chasing': 12054,
#     'Chat': 12715,
#     'Chat.': 12137,
#     'Chat80155': 601,
#     'Cheap': 11792,
#     'Check': 13324,
#     'Cheer': 9893,
#     'Cheers': 9167,
#     'Cheers,': 12728,
#     'Chef': 11984,
#     'Children': 11454,
#     'Chinatown': 8882,
#     'Chinese': 4282,
#     'Chk': 13275,
#     'Choose': 12408,
#     'Christians': 1558,
#     'Christmas': 3525,
#     'Christmas!': 2376,
#     'Christmas!Merry': 6176,
#     'Christmas...': 7078,
#     'Ciao!': 2319,
#     'Cine': 2110,
#     'City': 11688,
#     'Claim': 6614,
#     'Claim,': 6297,
#     'Claim.': 4024,
#     'Classic': 1685,
#     'Click': 6654,
#     'Clos1': 9185,
#     'Close': 10407,
#     'Club': 8279,
#     'Club.': 13081,
#     'Club4': 4970,
#     'Club:': 4973,
#     'Club>>': 3487,
#     'Co': 3412,
#     'Co.': 7792,
#     'Coca-Cola': 11637,
#     'Code': 5123,
#     'Code:': 5752,
#     'Coffee': 4979,
#     'Cold.': 6889,
#     'Colleagues': 10713,
#     'Colleagues.': 10532,
#     'Collect': 12595,
#     'Colour': 3485,
#     'Com': 297,
#     'Come': 9618,
#     'Companion': 3747,
#     'Company': 2824,
#     'Compass': 7065,
#     'Complete': 2522,
#     'Concentrate': 9597,
#     'Confidence:': 9191,
#     'Congrats': 6281,
#     'Congrats!': 7579,
#     'Congrats.': 3842,
#     'Congratulations': 4461,
#     'Congratulations!': 13556,
#     'Consider': 4615,
#     'Contact': 9160,
#     'Content': 3719,
#     'Convey': 9953,
#     'Cool': 11181,
#     'Cool,': 3800,
#     'Cool.': 9758,
#     'Cornwall': 8747,
#     'Correct': 5645,
#     'Correct.': 7428,
#     'Cos': 1562,
#     'Cost': 1735,
#     'Costa': 12387,
#     'Costs': 1693,
#     'Costå£1.50/pm,': 6689,
#     'Cougar-Pen': 12917,
#     'Could': 3832,
#     'Courageous': 7301,
#     'Coz': 11769,
#     'Coz..somtimes': 9699,
#     'Cps': 3833,
#     'Crab': 3543,
#     'Crack': 10790,
#     'Cramps': 3305,
#     'Crazy': 4734,
#     'Credit!': 12952,
#     'Croydon': 12615,
#     'Crucify': 923,
#     'Crying': 11706,
#     'Cs': 1648,
#     'Ctagg.': 996,
#     'Ctargg.': 13190,
#     'Cttargg.': 4092,
#     'Ctter.': 9070,
#     'Cttergg.': 67,
#     'Cud': 1771,
#     'Cup': 12844,
#     'Cust': 6535,
#     'CustCare:08718720201': 7978,
#     'CustCare:08718720201.': 4711,
#     'Customer': 3030,
#     'Cut': 4878,
#     'Cute': 13498,
#     'Cute:': 1232,
#     'Cutefrnd': 1345,
#     'Cutter.': 7995,
#     'Cuz': 4281,
#     'D': 11432,
#     'D=': 2725,
#     'DA': 11396,
#     'DABOOKS.': 11145,
#     'DADS': 7448,
#     'DAMMIT!!': 1626,
#     'DAN': 251,
#     'DARLIN': 10239,
#     'DAS': 5770,
#     'DATE': 8252,
#     'DATEBox1282EssexCM61XN': 2261,
#     'DAY': 12753,
#     'DAY!': 9270,
#     'DAY!2': 6259,
#     'DAY..U': 12840,
#     'DAYS': 1216,
#     'DAY\\"': 11266,
#     'DD': 2917,
#     'DE': 12007,
#     'DEAD': 13681,
#     'DECIDED': 7962,
#     'DEF': 796,
#     'DEFO': 207,
#     'DEL': 849,
#     'DENA': 7324,
#     'DETAILS': 12309,
#     'DID': 10434,
#     "DIDN'T": 1621,
#     'DIDNT': 2014,
#     'DIGITAL': 10428,
#     'DIRTY': 12351,
#     'DIS': 7201,
#     'DLF': 5942,
#     'DO': 5181,
#     'DOESDISCOUNT!SHITINNIT\\""': 11729,
#     'DOESNT': 116,
#     'DOGBREATH?': 2929,
#     'DOIN': 2694,
#     'DOIN?': 10414,
#     'DONE': 9630,
#     'DONE!': 5772,
#     'DONT': 429,
#     'DONåÕT': 4259,
#     'DOT': 2792,
#     'DOUBLE': 10311,
#     'DOWN': 8200,
#     'DOWNON': 830,
#     'DPS,': 4002,
#     'DRACULA': 8857,
#     'DRAW': 12683,
#     'DREAMS..': 4682,
#     'DREAMZ': 6899,
#     'DRUNK!': 3900,
#     'DUMB?': 4814,
#     'DVD': 11611,
#     'DVD!': 3445,
#     'Da': 8171,
#     'Dad': 13573,
#     'Dad.': 13358,
#     'Daddy': 3547,
#     'Dai': 5886,
#     'Damn': 1681,
#     'Damn,': 2852,
#     'Dan': 12184,
#     'Dare': 9904,
#     'Darling': 5284,
#     'Darren': 7211,
#     'Darren...': 12046,
#     'Dasara': 1893,
#     'Dat': 8980,
#     'Date': 6460,
#     'Dates': 5179,
#     'Dating': 4822,
#     'Dave': 13539,
#     'Day': 4289,
#     'Day!': 6906,
#     'Day,': 3523,
#     'Day.': 5932,
#     'Day...!!!': 7751,
#     'Day:)': 2353,
#     'Day\\"': 9523,
#     'De': 2747,
#     'Deal?': 12762,
#     'Dear': 257,
#     'Dear,': 4548,
#     'Dear,Me': 1366,
#     'Dear,regret': 5165,
#     'Dear,shall': 13085,
#     'Dear.': 11370,
#     'Dear...........': 2841,
#     'Dear..:)': 8343,
#     'Dear1': 9122,
#     'December': 9478,
#     'Deeraj': 9431,
#     'Def': 373,
#     'Del': 10042,
#     'Delhi': 10521,
#     'Deliver': 6863,
#     'Delivered': 733,
#     'DeliveredTomorrow?': 13599,
#     'Delivery': 12038,
#     'Den': 5621,
#     'Dependable': 6968,
#     'Depends': 8046,
#     'Derp.': 9527,
#     'Designation': 8086,
#     'Desires...,': 10846,
#     'Determined': 10853,
#     'Detroit': 10092,
#     'Detroit.': 417,
#     'Devils': 2392,
#     'Dey': 12129,
#     'Dial': 10468,
#     'Dick.': 8549,
#     'Dictionary': 11987,
#     'Did': 11209,
#     "Didn't": 2113,
#     'Die': 9677,
#     'Die...': 73,
#     'Digital': 8129,
#     'Dileep.thank': 4952,
#     'Din': 1305,
#     'Dint': 2814,
#     'Direct': 3042,
#     'Dis': 3841,
#     'Disconnect': 11100,
#     'Discussed': 4366,
#     'Diseases': 3202,
#     'Ditto.': 12697,
#     'Diwali': 1061,
#     'Dizzamn,': 11940,
#     'Dizzee': 7589,
#     'Dload': 12529,
#     'Dnt': 11728,
#     'Do': 8325,
#     'Doc': 6757,
#     'Doctor.': 437,
#     'Does': 725,
#     "Doesn't": 12093,
#     'Dogging': 3062,
#     'Doggy': 5385,
#     'Doing': 13149,
#     'Doll..:-D;-),': 11667,
#     'Dom': 6340,
#     'Don': 3981,
#     "Don't": 11162,
#     "Don't4get2text": 3155,
#     'Done': 5481,
#     'Dont': 865,
#     'DontCha': 9658,
#     'Don\x89Û÷t': 11449,
#     'Dorothy@kiefer.com': 3307,
#     'Double': 1899,
#     'DoubleMins': 9885,
#     'DoubleTxt': 11187,
#     'Download': 584,
#     'Dozens': 8126,
#     'Dr': 7017,
#     'Draw': 1535,
#     'Draw.': 7053,
#     'Dream': 1853,
#     'Drinks': 8681,
#     'Driver': 8695,
#     'Drop': 7844,
#     'Drop,': 13665,
#     'Duchess': 3349,
#     'Dude': 1861,
#     'Dude.': 55,
#     'Dun': 3182,
#     'Dunno': 588,
#     'Dunno,': 12140,
#     'Dvd': 240,
#     'E': 643,
#     'E-namous.': 5722,
#     'E-ternal.': 12586,
#     'E.G.23F.': 11242,
#     'E14': 10057,
#     'E=': 11414,
#     'EACHOTHER.': 10657,
#     'EASTENDERS': 5357,
#     'EAT': 3053,
#     'EH74RR': 2007,
#     'ELLO': 6609,
#     'ENC': 3058,
#     'END': 7611,
#     'ENG': 6467,
#     'ENGLAND': 2089,
#     'ENGLAND!': 11316,
#     'ENJOY': 3235,
#     'ENJOYIN': 271,
#     'ENTER': 150,
#     'ENTER.': 11307,
#     'ENTRY': 5119,
#     'ESPECIALLY': 8363,
#     'EURO': 12899,
#     'EURO2004': 1173,
#     'EVE': 1841,
#     'EVE.': 6712,
#     'EVEN': 4707,
#     'EVENING*': 4978,
#     'EVERY': 2918,
#     'EVERY1': 9734,
#     'EVERYTHIN': 2234,
#     'EVONE': 7957,
#     'EXACT': 7230,
#     'EXAMS': 8189,
#     'EXETER': 528,
#     'EXORCIST,': 3556,
#     'EXP.': 5392,
#     'EXPLAIN': 11847,
#     'EXPLOSIVE': 9879,
#     'EXTREME': 8097,
#     'Each': 10524,
#     'Early': 8808,
#     'Earth...': 4543,
#     'Easter': 1779,
#     'Easy': 9974,
#     'Eat': 7259,
#     'Echo': 7319,
#     'Eckankar': 5838,
#     'Edison': 721,
#     'Ee': 10261,
#     'Eek': 108,
#     'Eek!': 1136,
#     'Eerie': 9251,
#     'Egbon': 5922,
#     'Eh': 5306,
#     'Eire.': 11195,
#     'Either': 13120,
#     'Ela': 187,
#     'Elvis': 8222,
#     'Em,': 804,
#     'Email': 6036,
#     'Emily': 10003,
#     'Emotion': 11540,
#     'En': 3136,
#     'End?': 8285,
#     'Energy': 12435,
#     'Energy!': 8039,
#     'England': 225,
#     'Enjoy': 6361,
#     'Enjoy!': 8932,
#     'Enjoy,': 12535,
#     'Enna': 4552,
#     'Er': 12450,
#     'Erm': 2530,
#     'Erm.': 5990,
#     'Erm...': 12567,
#     'Err...': 2120,
#     'Erutupalam': 7866,
#     'Ese': 2088,
#     'Especially': 4447,
#     'Euro': 10015,
#     'Euro2004': 10481,
#     'EuroDisinc': 13114,
#     'Europe': 6218,
#     'Eve': 1905,
#     'Even': 4248,
#     'Evening': 8047,
#     'Evenings': 12591,
#     'Ever': 9487,
#     'Ever.': 3852,
#     'Every': 12780,
#     'Everyday': 11656,
#     'Everyone': 3929,
#     'Everything': 1083,
#     'Everytime...': 8818,
#     'Evn': 3337,
#     'Evr"': 10392,
#     'Evrey': 13315,
#     'Evry': 2883,
#     'Ew': 7927,
#     'Exactly.': 1988,
#     'Exam': 6980,
#     'Excellent!': 5361,
#     'Excellent,': 2076,
#     'Executive': 1438,
#     'Exorcism': 4512,
#     'Expected...': 8972,
#     'Expecting': 4070,
#     'Expires': 8589,
#     'Explain!': 10166,
#     'Express': 6370,
#     'Expression': 8036,
#     'Extra': 4497,
#     'Eyes': 8251,
#     'F': 11146,
#     'F=': 9164,
#     'FA': 3129,
#     'FANCY': 5614,
#     'FANTASIES': 1334,
#     'FANTASTIC': 7199,
#     'FANTASY': 731,
#     'FAR': 2912,
#     'FEEL': 4131,
#     'FFFFUUUUUUU': 652,
#     'FIELDOF': 6026,
#     'FIFA': 1072,
#     'FIFTEEN': 10822,
#     'FILTH': 4619,
#     'FINAL': 3271,
#     'FIND': 11139,
#     'FINE': 1619,
#     'FINEST,': 5187,
#     'FINISH': 5856,
#     'FIRST': 4325,
#     'FIT': 12964,
#     'FLAG': 3590,
#     'FLOWER': 10663,
#     'FM...you': 9159,
#     'FML': 5626,
#     'FONE': 9239,
#     'FONE,': 13592,
#     'FOR': 9289,
#     "FR'NDSHIP": 4656,
#     'FRAN': 4726,
#     'FRANYxxxxx': 11079,
#     'FREE': 9083,
#     'FREE!': 4870,
#     'FREE-Nokia': 3512,
#     'FREE.': 6847,
#     'FREE2DAY': 8132,
#     'FREE>Ringtone!': 1873,
#     'FREE>Ringtone!Reply': 12536,
#     'FREEFONE': 10231,
#     'FREEMSG:': 6020,
#     'FREEPHONE': 1224,
#     'FRESHERS': 9358,
#     'FRIEND': 4144,
#     'FRIENDS': 4181,
#     'FRIENDSHIP': 1789,
#     'FRND': 4994,
#     'FRNDSHIP\\""': 5425,
#     'FRNDS\\"': 9989,
#     'FROM': 6547,
#     'FUCK': 1847,
#     'FUCKED': 7194,
#     'FUCKIN': 470,
#     'FUCKING': 6776,
#     'FUDGE': 4402,
#     'FUNNY!': 756,
#     'Face.:)': 10007,
#     'Facebook?': 8559,
#     'Fails': 13695,
#     'Fair': 3519,
#     'Faith': 12139,
#     'Fancy': 1420,
#     'Fantasy': 4513,
#     'Fat.': 12911,
#     'Fear': 1193,
#     'Feb': 13817,
#     'Feel': 12019,
#     'Feeling': 3303,
#     'Feels': 4820,
#     'Fffff.': 13368,
#     'Ffffffffff.': 7235,
#     'Fifty?': 2170,
#     'Fighting': 1718,
#     'Filling': 5842,
#     'Filthy': 10226,
#     'Final': 6274,
#     'Finally': 3394,
#     'Find': 9065,
#     'Fine': 3103,
#     'Fine.': 6659,
#     'Fingers': 2850,
#     'Finish': 8910,
#     'Finished': 10211,
#     'First': 3140,
#     'Flag': 8209,
#     'Flight': 3662,
#     'Flirt!!': 426,
#     'Flung': 12746,
#     'Fml': 5538,
#     'Foley': 13345,
#     'Follow': 10202,
#     'Food': 11405,
#     'Fools': 13220,
#     'Football': 13217,
#     'For': 12970,
#     'Force.': 4968,
#     'Forever': 12962,
#     'Forevr...': 5799,
#     'Forgets': 4564,
#     'Forgot': 356,
#     'Found': 10615,
#     'Fr': 12965,
#     'Fredericksburg': 12250,
#     'Free': 2696,
#     'Free!': 1445,
#     'Free,': 6527,
#     'Free-message:': 349,
#     'FreeMSG': 1163,
#     'FreeMsg': 2611,
#     'FreeMsg:': 12425,
#     'FreeMsg:Feelin': 2117,
#     'FreeMsg>FAV': 11983,
#     'Freemsg:': 1459,
#     'Fresh': 9118,
#     'Fri': 12198,
#     'Friday': 8389,
#     'Friday,': 10,
#     'Friday.': 11295,
#     'Friends': 2068,
#     'Friends..!!': 10406,
#     'Friendship': 3120,
#     'Friendship,Mother,Father,Teachers,Childrens': 4141,
#     'Friendship\\"...': 5963,
#     'Frnd': 6844,
#     'From': 12742,
#     'From:': 11302,
#     'Fuck': 8436,
#     'Fuck,': 7824,
#     'Fun': 10825,
#     'Funny': 5458,
#     'Future': 963,
#     'Fwiw': 8232,
#     'Fyi': 9408,
#     'G': 11949,
#     'G.': 11703,
#     'G.B.': 12605,
#     'G.W.R': 5045,
#     'G2': 8149,
#     'GAIL': 5099,
#     'GANG': 5555,
#     'GAS': 1711,
#     'GBP': 11419,
#     'GBP/week!': 6640,
#     'GBP1.50/week': 6223,
#     'GBP4.50/week.': 5235,
#     'GBP5/month.': 10200,
#     'GENDER': 3319,
#     'GENT!': 709,
#     'GET': 8563,
#     'GETTIN': 2784,
#     'GHOST,': 9537,
#     'GIFTS!!': 8677,
#     'GIMMI': 7907,
#     'GIRL': 8067,
#     'GIRL,': 9316,
#     'GIRL.': 5895,
#     'GIRLS': 3270,
#     'GIVE': 12626,
#     'GM': 6033,
#     'GM+GN+GE+GN:)': 823,
#     'GMW': 9567,
#     'GO': 6780,
#     'GO!': 10954,
#     'GOD': 7057,
#     'GOD,I': 11708,
#     'GOIN': 3991,
#     'GOING': 6355,
#     'GONE(U': 2538,
#     'GONNA': 12941,
#     'GONNAMISSU': 7986,
#     'GOOD': 10838,
#     'GOODEVENING': 93,
#     'GOODFRIEND': 8335,
#     'GOODMORNING': 9722,
#     'GOODMORNING"': 10494,
#     'GOODMORNING:)': 13614,
#     'GOODNIGHT': 13707,
#     'GOODNOON:)': 781,
#     'GOODTIME!OLI': 10946,
#     'GORGEOUS': 2297,
#     'GOSS!x': 6109,
#     'GOT': 11917,
#     'GOTTA': 4311,
#     'GOWER': 791,
#     'GR8FUN': 10960,
#     'GRAVEL': 2397,
#     'GREAT': 5062,
#     'GROW.RANDOM!': 5858,
#     'GSOH?': 11376,
#     'GUARANTEED': 2708,
#     'GUARANTEED!': 9399,
#     'GUARANTEED.': 7632,
#     'GUD': 2008,
#     'GURL': 7711,
#     'Gam': 12775,
#     'Game': 9966,
#     'Games': 4303,
#     'Games,': 8969,
#     'Gamestar': 13165,
#     'Ganesh': 13420,
#     'Gary': 5315,
#     'Gay': 1362,
#     'Gaze': 2098,
#     'Gd': 1317,
#     'Ge:-)..': 4226,
#     'Gee,later': 8103,
#     'Gee...': 8887,
#     'Geeee': 2684,
#     'Geeeee': 259,
#     'Genius': 7970,
#     "George's": 378,
#     'Germany': 3035,
#     'Get': 2718,
#     'Gettin': 10027,
#     'Gibbs': 3546,
#     'Gift': 7424,
#     'Gimme': 11970,
#     'Gin': 12020,
#     "Girl'": 1603,
#     'Girls': 13202,
#     'Give': 6851,
#     'Glad': 702,
#     'Gn"': 6497,
#     'Gnarls': 8429,
#     'Go': 5140,
#     'GoTo': 13646,
#     'God': 8786,
# ...
#     'via': 2074,
#     'vibrate': 10883,
#     'vibrator': 1493,
#     'vic': 6551,
#     'victors': 8146,
#     'vid': 1990,
#     'video': 9003,
#     'video.': 3738,
#     'video/pic': 9017,
#     'videochat': 11859,
#     'videosound': 239,
#     'videosounds+2': 5049,
#     'view': 3978,
#     'vijay': 3773,
#     'vikky': 11473,
#     'vikky,': 4792,
#     'vikky..': 1523,
#     "vikky..i'm": 8841,
#     'vill': 8408,
#     'village': 85,
#     'village,': 11745,
#     'violated': 3453,
#     'violated.': 1846,
#     'violence': 4395,
#     'virgins': 1481,
#     'virtual': 8110,
#     'visa': 3804,
#     'visionsms.com': 3158,
#     'visit': 3259,
#     'visit.need': 10929,
#     'visiting': 9981,
#     'visitors,': 6697,
#     'vital': 3048,
#     'vitamin': 6747,
#     'vivek..': 12347,
#     'vl': 2359,
#     'vodafone': 9413,
#     'vodka...': 8669,
#     'voice': 13022,
#     'voice.': 12540,
#     'voice...': 3811,
#     'voice.....': 332,
#     'voicemail.': 11740,
#     'volcanoes': 12196,
#     'vomit': 6666,
#     'vomitin.': 7668,
#     'vomiting': 10103,
#     'vote': 5973,
#     'vote?': 3969,
#     'voted': 8884,
#     'voucher': 12670,
#     'voucher,': 11461,
#     'voucher.': 9876,
#     'vouchers': 4242,
#     'vouchers!': 9076,
#     'vouchers-Text': 12474,
#     'vry': 6237,
#     'vs.': 483,
#     'vth': 3290,
#     'w': 11249,
#     'w/c': 10159,
#     'w/question.': 13055,
#     'w1t1jy': 5891,
#     'w8in': 12313,
#     'wa.': 10909,
#     'wad?': 5408,
#     'wadebridge.I': 5508,
#     'wahala.': 10894,
#     'wahay.': 4800,
#     'waheed': 3823,
#     'waheeda': 12205,
#     'waht': 2947,
#     'wait': 11138,
#     'wait,': 9895,
#     'wait.': 529,
#     'wait?': 1313,
#     'waited': 4936,
#     'waitin': 12497,
#     'waiting': 5616,
#     'waiting..\\"': 2766,
#     'wake': 6927,
#     'wake,': 4862,
#     'wake.': 7852,
#     'waking': 1786,
#     'waliking': 13840,
#     'walk': 8949,
#     'walkabout': 4607,
#     'walked': 13823,
#     'walkin': 636,
#     'walking': 2220,
#     'walking..': 8901,
#     'walks': 5259,
#     'wall?': 10627,
#     'wallet': 2516,
#     'walls': 10745,
#     'walmart': 8804,
#     'walmart.': 12671,
#     'walsall': 6578,
#     'wamma': 13580,
#     'wan': 7083,
#     'wan...': 4523,
#     'wana': 2986,
#     'wanna': 13061,
#     'wanna?': 7409,
#     'want': 541,
#     'want.': 12688,
#     'want2come.': 6993,
#     'want?': 13333,
#     'wanted': 2229,
#     'wanting': 9610,
#     'wants': 12052,
#     'wap': 4084,
#     'wap.': 7921,
#     'warm': 5788,
#     'warm.': 6611,
#     'warm?': 8342,
#     'warming': 5061,
#     'warned': 8774,
#     'warning': 10526,
#     'warranty.': 8742,
#     'warwick,': 157,
#     'was': 9360,
#     'was.': 10921,
#     'washob': 10508,
#     "wasn't": 3008,
#     'wasnåÕt': 8213,
#     'waste': 6332,
#     'waste.': 822,
#     'wasting.': 7573,
#     'wat': 8322,
#     "wat'll": 2412,
#     "wat's": 10210,
#     'wat,': 1360,
#     'wat.': 3589,
#     'wat..': 5456,
#     'wat...': 13008,
#     'wat?': 1567,
#     'watch': 10165,
#     'watch.': 6954,
#     'watch...': 7750,
#     'watches': 12208,
#     'watchin': 13822,
#     'watching': 817,
#     'watchng': 9913,
#     'water': 2786,
#     'water,': 841,
#     'water.': 13228,
#     'watevr': 7061,
#     'wats': 2433,
#     'watts.': 5263,
#     'waves': 12047,
#     'way': 8803,
#     'way!': 12860,
#     'way&this': 7081,
#     'way,': 7186,
#     'way.': 8666,
#     'way?': 2679,
#     'wc1n3xx': 928,
#     'we': 11998,
#     "we'll": 1168,
#     "we're": 1866,
#     "we've": 7091,
#     'weak': 7538,
#     'weakness': 4351,
#     'weaknesses': 9710,
#     'wear': 2174,
#     'wearing': 8517,
#     'wearing?': 11164,
#     'weaseling': 10168,
#     'weasels...': 7722,
#     'weather': 6838,
#     'weather.': 3461,
#     'web': 1172,
#     'web2mobile': 12708,
#     'webadres': 3862,
#     'website.': 3771,
#     'website..now': 8329,
#     'website?': 4662,
#     'wed': 7737,
#     'wed,': 4646,
#     'wed.': 8937,
#     'weddin': 9958,
#     'wedding': 11542,
#     'wednesday': 9343,
#     'wednesday,': 4426,
#     'wednesday.': 321,
#     'weds': 4920,
#     'wee': 8405,
#     'weed': 13265,
#     'weed-deficient': 13059,
#     'week': 13802,
#     'week!': 8899,
#     "week's": 1696,
#     'week,': 9939,
#     'week-stop': 2606,
#     'week.': 9071,
#     'week.:/': 13379,
#     'week.|': 8150,
#     'week?': 2474,
#     'week??': 7575,
#     'weekdays': 12558,
#     'weekend': 12638,
#     'weekend!': 4658,
#     "weekend's": 4253,
#     'weekend.': 5600,
#     'weekend?': 13369,
#     'weekends': 7411,
#     'weekends?': 7275,
#     'weekly': 5667,
#     'weekly!': 1379,
#     'weeks': 803,
#     'weeks!': 11595,
#     'weeks>': 13639,
#     'weigh': 12075,
#     'weighed': 878,
#     'weight': 1040,
#     'weight!': 9196,
#     'weight,': 9288,
#     'weight.': 6143,
#     'weight...': 5225,
#     'weight...Haha...': 8846,
#     'weird': 7318,
#     'weird,': 10632,
#     'weirdest': 1356,
#     'weirdo?': 903,
#     'weirdy': 5724,
#     'welcome': 8659,
#     'welcome.': 7313,
#     'welcome...': 12579,
#     'well': 45,
#     'well!': 1878,
#     'well!!': 2862,
#     'well,': 3350,
#     'well.': 463,
#     'well...': 2191,
#     'well..:)': 6416,
#     'well.you': 1361,
#     'well?': 11490,
#     'welp': 981,
#     'welp?': 4981,
#     'wen': 10101,
#     'went': 10328,
#     'wer': 10465,
#     'were': 1079,
#     'were/are': 10205,
#     "weren't": 4737,
#     'wesley': 9889,
#     'wesleys': 387,
#     'west': 6346,
#     'western': 1120,
#     'westonzoyland,': 9375,
#     'westshore': 4273,
#     'wet': 4784,
#     'wet.': 3231,
#     'wet?': 2518,
#     'wetherspoons?': 5227,
#     'we\x89Û÷ll': 13314,
#     'we\x89Û÷re': 4208,
#     'weåÕve': 4969,
#     'what': 4175,
#     'what!': 6294,
#     "what's": 10938,
#     'what,': 11099,
#     'what...': 3205,
#     'whatever': 1124,
#     'whatever,': 8461,
#     'whatever.': 13718,
#     'whats': 6366,
#     'wheel': 11704,
#     'wheellock?': 9499,
#     'when': 11403,
#     'when,': 2038,
#     'when...': 9363,
#     'whenever': 7292,
#     'where': 3939,
#     "where's": 6987,
#     'where.': 9398,
#     'where?': 11292,
#     'where?btw': 12164,
#     'whereare': 11390,
#     'wherever': 13238,
#     'whether': 1551,
#     'which': 11657,
#     'while': 6910,
#     'while,': 8609,
#     'while,&amp;': 13390,
#     'while.': 9813,
#     'whillTake': 12826,
#     'white': 10353,
#     'white.': 5469,
#     'whn': 7909,
#     'who': 2420,
#     "who's": 1989,
#     'who.': 7565,
#     'who?': 5459,
#     'whole': 10277,
#     'whom': 6628,
#     'whos': 7494,
#     'whose': 6422,
#     'whr': 530,
#     'why': 8502,
#     'why?': 5522,
#     'wi': 12539,
#     'wid': 8779,
#     'widelive.com/index.': 5804,
#     'wif': 3345,
#     'wife': 818,
#     'wife,': 7697,
#     'wife.': 13558,
#     'wife....': 11051,
#     'wifes.': 1666,
#     'wifi': 10828,
#     'wihtuot': 3854,
#     'wikipedia.com': 9816,
#     'wil': 1014,
#     'wildest': 6494,
#     'wildlife': 11201,
#     'will': 4437,
#     'will!': 1825,
#     'will,': 13259,
#     'willing': 2052,
#     'willpower': 11496,
#     'win': 6524,
#     'win150ppmx3age16': 1060,
#     'wind': 9234,
#     'wind.': 7054,
#     'window:-)': 9891,
#     'windows': 12265,
#     'windows,': 8975,
#     'winds': 4942,
#     'windy.': 8616,
#     'wine': 218,
#     'wined': 2652,
#     'wining': 9309,
#     'winner': 11687,
#     'winner!': 5272,
#     'wins': 6414,
#     'wins.': 8836,
#     'winterstone': 1318,
#     'wipro': 13752,
#     'wipro:)you': 124,
#     'wisdom': 7025,
#     'wisdom..': 78,
#     'wise': 11366,
#     'wish': 9131,
#     'wish!': 1119,
#     'wish.': 7305,
#     'wisheds.': 1544,
#     'wishes': 4884,
#     'wishin': 230,
#     'wishing': 11387,
#     'wishlist': 5232,
#     'wiskey': 7560,
#     'wit': 13826,
#     'with': 5136,
#     'with:': 6746,
#     'withdraw': 4262,
#     'wither': 7857,
#     'within': 9814,
#     'without': 595,
#     'witin': 1719,
#     'witot': 13297,
#     'witout': 10690,
#     'wiv': 4951,
#     'wizzle': 3740,
#     'wk': 4967,
#     'wk!': 10966,
#     'wk,': 10154,
#     'wk.': 1304,
#     'wkend': 5691,
#     'wkend.': 6761,
#     'wkg': 2887,
#     'wkly': 5697,
#     'wknd': 8101,
#     'wks!': 2195,
#     'wlcome': 2809,
#     'wld': 3726,
#     'wml?id=1b6a5ecef91ff9*37819&first=true18:0430-JUL-05': 3648,
#     'wnt': 11717,
#     'wo': 3938,
#     'woke': 4598,
#     'woken': 9967,
#     'woman': 2805,
#     'womdarfull': 1455,
#     'women': 12068,
#     'won': 10217,
#     'won!': 2909,
#     "won't": 365,
#     'won.': 6692,
#     'wondar': 4161,
#     'wondarfull': 2043,
#     'wonder': 9704,
#     'wonder...': 9978,
#     'wonderful': 9701,
#     'wonderful.': 11071,
#     'wondering': 10087,
#     'wondering,': 6448,
#     'wonders': 8521,
#     'wont': 5319,
#     'wont.': 10637,
#     'woould': 6309,
#     'woozles': 11455,
#     'word': 1332,
#     'word).': 6187,
#     'word.': 1289,
#     'word.....not': 9789,
#     'word:': 280,
#     'word:COLLECT': 1274,
#     'word:START': 3749,
#     'words': 12157,
#     'words,': 13852,
#     'words-': 273,
#     'words.': 2635,
#     'words...': 11505,
#     'words....': 2075,
#     'work': 9180,
#     'work,': 3949,
#     'work,Love': 9737,
#     'work.': 11963,
#     'work..': 13754,
#     'work...': 9844,
#     'work?': 3930,
#     'workAnd': 8792,
#     'workage.': 2826,
#     'workin': 315,
#     'workin.': 7475,
#     'working': 10260,
#     'working!': 2628,
#     'working.': 10635,
#     'working?': 5750,
#     'workout': 5210,
#     'works.': 8474,
#     'world': 12091,
#     'world,': 191,
#     'world,may': 8927,
#     'world.': 8634,
#     'world....gnun': 12748,
#     'world:).very': 2866,
#     'worlds': 9771,
#     'worried': 169,
#     'worried.': 2201,
#     'worries': 1054,
#     'worries,': 9628,
#     'worries.': 2307,
#     'worry': 9186,
#     'worry,': 11076,
#     'worry.': 13247,
#     'worry..': 5274,
#     'worry...use': 11750,
#     'worrying': 10848,
#     'worse': 5127,
#     'worse,': 13362,
#     'worst': 2582,
#     'worth': 11029,
#     'worthless': 9983,
#     'wot': 430,
#     'wot?': 10818,
#     'woul': 1239,
#     'would': 7097,
#     'would,': 13431,
#     "wouldn't": 10198,
#     'wow': 9954,
#     'wow.': 9192,
#     'wrecked.': 12950,
#     'wrench': 10295,
#     'write': 7215,
#     'writhing': 5196,
#     'wrking': 4053,
#     'wrks': 5553,
#     'wrnog..': 2471,
#     'wrong': 8315,
#     'wrong!!': 4074,
#     'wrong,': 8316,
#     'wrongly': 6331,
#     'wrote.': 10622,
#     'ws': 13520,
#     'wt': 1575,
#     'wtc': 475,
#     'wtf': 8963,
#     'wth': 6425,
#     'wthout': 11669,
#     'wud': 5112,
#     "wudn't": 6790,
#     'wuld': 7330,
#     'wuldnt': 10549,
#     'wun': 9438,
#     'www.07781482378.com': 1295,
#     'www.4-tc.biz': 8413,
#     'www.80488.biz': 2779,
#     'www.Applausestore.com': 5992,
#     'www.B4Utele.com': 9642,
#     'www.Idew.com': 172,
#     'www.Ldew.com': 12709,
#     'www.Ldew.com.subs16+1win150ppmx3': 5243,
#     'www.Ldew.com1win150ppmx3age16': 3552,
#     'www.SMS.ac/u/bootydelious': 4847,
#     'www.SMS.ac/u/nat27081980': 6690,
#     'www.areyouunique.co.uk': 10024,
#     'www.bridal.petticoatdreams.co.uk': 3861,
#     'www.clubzed.co.uk': 3609,
#     'www.cnupdates.com/newsletter.': 7568,
#     'www.comuk.net': 11842,
#     'www.dbuk.net': 3050,
#     'www.flirtparty.us': 6104,
#     'www.fullonsms.com': 869,
#     'www.getzed.co.uk': 8832,
#     'www.ldew.com': 12881,
#     'www.movietrivia.tv': 43,
#     'www.music-trivia.net': 9345,
#     'www.orange.co.uk/ow': 3258,
#     'www.phb1.com': 4695,
#     'www.regalportfolio.co.uk.': 4539,
#     'www.ringtoneking.co.uk!': 12169,
#     'www.ringtones.co.uk,': 2213,
#     'www.rtf.sphosting.com': 3688,
#     'www.smsco.net': 11589,
#     'www.t-c.biz': 11092,
#     'www.textcomp.com': 11598,
#     'www.textpod.net': 13481,
#     'www.tkls.com': 8550,
#     'www.txt-2-shop.com': 7310,
#     'www.txt43.com': 13320,
#     'www.txt82228.com.': 11920,
#     'www.txttowin.co.uk': 13338,
#     'www.win-82050.co.uk': 10820,
#     'x': 10821,
#     "x'mas.": 7642,
#     'x-net': 12166,
#     'x.': 7084,
#     'x\\""': 12268,
#     'xafter': 3742,
#     'xam': 4486,
#     'xavier': 3509,
#     'xin': 8421,
#     'xmas': 5672,
#     'xmas!': 7535,
#     'xx': 10596,
#     'xxSP': 7280,
#     'xxx': 6238,
#     'xxx.': 7758,
#     'xxx\\""': 6007,
#     'xxxmobilemovieclub.com?n=QJKGIGHJJGCBL': 6342,
#     'xxxxxxx\\""': 3599,
#     'xxxxxxxx': 12344,
#     'xxxxxxxxxxxxxX': 6041,
#     'xy': 11730,
#     'xy?': 2383,
#     'y': 13451,
#     "y'day": 12948,
#     'y.': 8276,
#     'ya': 12666,
#     'ya!!': 9497,
#     'ya,': 8412,
#     'ya.': 9579,
#     'ya...': 5599,
#     'yahoo': 6183,
#     'yalrigu': 3370,
#     'yam': 7974,
#     'yan': 1175,
#     'yay': 1889,
#     'yay!': 2102,
#     'yck': 3301,
#     'yck?': 10783,
#     'yeah': 10160,
#     'yeah!': 13249,
#     'yeah,': 3968,
#     'yeah?': 5037,
#     'year': 6571,
#     'year,': 6122,
#     'year.': 11045,
#     'year?': 11845,
#     'years': 7379,
#     'years!': 8897,
#     'years,': 4165,
#     'years.': 13488,
#     'years?': 9108,
#     'yelling': 693,
#     'yelling.': 11936,
#     'yellow': 12383,
#     'yep': 985,
#     'yer': 735,
#     'yes': 3629,
#     'yes,': 5517,
#     'yes.': 6619,
#     'yest': 10336,
#     'yest...': 9780,
#     'yest?': 7755,
#     'yesterday': 855,
#     'yesterday!': 104,
#     'yesterday,': 226,
#     'yesterday.': 10925,
#     'yesterday?': 2033,
#     'yet': 3976,
#     'yet)': 5384,
#     'yet,': 8955,
#     'yet.': 9475,
#     'yet..': 7076,
#     'yet...': 2375,
#     'yet?': 8467,
#     "yetty's": 8812,
#     'yetunde': 154,
#     'yi': 5661,
#     'yifeng': 1595,
#     'yijue': 13728,
#     'yijue,': 304,
#     'yijue.': 5613,
#     'yijue...': 1180,
#     'yijue@hotmail.com': 13340,
#     'ym': 6624,
#     'yo': 7437,
#     'yo,': 13346,
#     'yo-Here': 10729,
#     'yo.': 12375,
#     'yo?': 302,
#     'yoga': 11244,
#     'yoga...': 10695,
#     'yogasana': 13645,
#     'yogasana?': 1976,
#     'yor': 424,
#     'yorge': 5288,
#     'you': 3755,
#     'you!': 12803,
#     'you!To': 1015,
#     "you'd": 9915,
#     "you'ld": 5086,
#     "you'll": 1337,
#     "you're": 13536,
#     "you've": 7399,
#     'you,': 7912,
#     'you,so': 13864,
#     'you.': 7228,
#     'you..': 785,
#     'you...': 13208,
#     'you....dear.with': 8877,
#     'you...money': 8746,
#     'you.:)k:)where': 7659,
#     'you.my': 2452,
#     'you.thats': 145,
#     'you/carlos': 7439,
#     'you:)any': 13612,
#     'you:-)': 3926,
#     'you:-.': 627,
#     'you?': 3816,
#     'you?how': 7706,
#     'you?when': 12165,
#     'youPhone': 1764,
#     'your': 7496,
#     'your"': 5870,
#     'youre': 10401,
#     'yourinclusive': 8311,
#     'yours': 8216,
#     'yours,': 5629,
#     'yours.': 2249,
#     'yourself': 5624,
#     'yourself,': 3761,
#     'yourself.': 3972,
#     'yourself...': 13054,
#     'youuuuu': 1013,
#     'youwanna': 10285,
#     'you\x89Û÷ll': 5863,
#     'youåÕre': 10712,
#     'yowifes.': 10273,
#     'yr': 2736,
#     'yrs': 9350,
#     'yrs.': 11862,
#     'ystrday.ice': 4022,
#     'yummy': 7604,
#     'yun': 5330,
#     'yuo': 11290,
#     'yuou': 12739,
#     'zac': 5628,
#     'zealand.': 954,
#     'zed': 10388,
#     'zhong': 7753,
#     'zoom': 10069,
#     'zyada': 11530,
#     '|': 10693,
#     '||': 11521,
#     '~': 13654,
#     '\x89Û_': 12996,
#     '\x89Û_.': 8415,
#     '\x89Û_Thanks': 7906,
#     '\x89ÛÏ': 9583,
#     '\x89ÛÏHarry': 10061,
#     '\x89ÛÒ': 2587,
#     'Ì_': 1266,
#     "Ì_'ll": 5917,
#     'Ì_.': 6214,
#     'Ì_...': 4622,
#     'Ì_?': 12415,
#     'ÌÏ': 3022,
#     "ÌÏ'll": 10229,
#     'å£1': 9190,
#     'å£1,500': 7242,
#     'å£1.50': 1521,
#     'å£1.50.': 3622,
#     'å£1.50/msg': 12921,
#     'å£1.50/msg.': 2067,
#     'å£1.50/week.': 4398,
#     'å£1.50/wk."': 8484,
#     'å£1.50ea.': 1294,
#     'å£1.50perWKsub': 6396,
#     'å£1.50pm': 13168,
#     'å£1.50pmmorefrommobile2Bremoved-MobyPOBox734LS27YF': 1509,
#     'å£1/minMobsmoreLKPOBOX177HP51FL': 1526,
#     'å£10': 10772,
#     'å£10)': 8849,
#     'å£10,000': 12490,
#     'å£100': 2336,
#     'å£100,000': 11275,
#     'å£1000': 4925,
#     'å£1000.': 3531,
#     'å£12': 6270,
#     'å£1250': 4725,
#     'å£1450': 8668,
#     'å£150': 11553,
#     'å£1500': 3883,
#     'å£1million': 6112,
#     'å£2,000': 3722,
#     'å£200': 2928,
#     'å£2000': 4272,
#     'å£250': 7578,
#     'å£250k': 10650,
#     'å£3': 9572,
#     'å£3.00': 6794,
#     'å£3/wk': 4171,
#     'å£33.65': 6296,
#     'å£350': 4873,
#     'å£350!': 2822,
#     'å£4.50.': 10408,
#     'å£400': 2130,
#     'å£48,': 8334,
#     'å£5': 6481,
#     'å£5/month': 4475,
#     'å£50': 7445,
#     'å£50-å£500.': 4557,
#     'å£500': 2859,
#     'å£500.': 11399,
#     'å£5000': 3712,
#     'å£5000,': 554,
#     'å£5000.00': 12484,
#     'å£50award.': 13530,
#     'å£54.': 4154,
#     'å£6': 3454,
#     'å£600.': 906,
#     'å£71.': 9900,
#     'å£75,000.': 8010,
#     'å£79': 3781,
#     'å£800': 4811,
#     'å£900': 2637,
#     'å£s': 8361,
#     'åÈ10': 12247,
#     'åÐ': 6839,
#     'åÒHarry': 7415,
#     "åÒIt's": 10655,
#     'åÔMORROW.': 5605,
#     'åÔrents': 11089}

# %% [markdown]
# We are going to use the count of words as the input to our neural network. The `vocab_vector` will have columns for all the words in our training data in the form of `{key: value}` i.e `{word: count}` as held by the `word_column_dict`  python `Dictionary`. The individual word counts in any particular text is updated from 0 to a number based on a word's total count in any single text.
#
# This means that the words with a higher count might have a higher weight in determining whether a text is a spam or not.

# %%
def update_input_layer(text):
    pp.pprint(text)
    global vocab_vector
    
    # clear out previous state, reset the vector to be all 0s
    vocab_vector *= 0
    for word in text.split(" "):
        vocab_vector[0][word_column_dict[word]] += 1

update_input_layer(training_data["text"][random.randrange(0,4572,4)])
pp.pprint(vocab_vector)
# Out:
# 'Will it help if we propose going back again tomorrow'
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %% [markdown]
# ### Build the SpamClassificationNeuralNetwork

# %%
import time
import sys

# %%
# Let's tweak our network from before to model these phenomena
class SpamClassificationNeuralNetwork(object):
    def __init__(self, training_data, num_hidden_nodes = 10, num_epochs = 10, learning_rate = 0.01):
        # set our random number generator 
        np.random.seed(1)
        # pre-process data
        self.pre_process_data(training_data)
        
        self.num_features = len(self.vocab)
        self.vocab_vector = np.zeros((1,len(self.vocab)))
        self.num_input_nodes = self.num_features
        self.num_hidden_nodes = num_hidden_nodes
        self.num_epochs = num_epochs
        self.num_output_nodes = 1
        self.learning_rate = learning_rate

        # Initialize weights
        self.weights_i_h = np.random.randn(self.num_input_nodes, self.num_hidden_nodes)
        self.weights_h_o = np.random.randn(self.num_hidden_nodes, self.num_output_nodes)
        
    def forward_backward_propagate(self, text, label):
        ### Forward pass ###
        # Input Layer
        self.update_input_layer(text)
        # Hidden layer
        hidden_layer = self.vocab_vector.dot(self.weights_i_h)
        # Output layer
        output_layer = self.sigmoid(hidden_layer.dot(self.weights_h_o))
        
        ### Backward pass ###
        # Output error
        output_layer_error = output_layer - label 
        output_layer_delta = output_layer_error * self.sigmoid_derivative(output_layer)

        # Backpropagated error - to the hidden layer
        hidden_layer_error = output_layer_delta.dot(self.weights_h_o.T) #
        # hidden layer gradients - no nonlinearity so it's the same as the error
        hidden_layer_delta = output_layer_error

        # update the weights - with grdient descent
        self.weights_h_o -= hidden_layer.T.dot(output_layer_delta) * self.learning_rate
        self.weights_i_h -= self.vocab_vector.T.dot(hidden_layer_delta) * self.learning_rate
        
        if(np.abs(output_layer_error) < 0.5):
                self.correct_so_far += 1
        
        
    
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    
    def sigmoid_derivative(self,x):
        return x * (1 - x)

        
    def train(self):
        for epoch in range(self.num_epochs):
            self.correct_so_far = 0
            start = time.time()

            for i in range(len(training_data)):
                # Forward and Back Propagation
                self.forward_backward_propagate(training_data["text"][i], training_data["label_tag"][i])

                samples_per_second = i / float(time.time() - start + 0.001)

                sys.stdout.write("\rEpoch: "+ str(epoch)
                                 +" Progress: " + str(100 * i/float(len(training_data)))[:4] 
                                 + " % Speed(samples/sec): " + str(samples_per_second)[0:5] 
                                 + " #Correct: " + str(self.correct_so_far) 
                                 + " #Trained: " + str(i+1) 
                                 + " Training Accuracy: " + str(self.correct_so_far * 100 / float(i+1))[:4] + "%")
            print("")
        
    def pre_process_data(self, training_data):
        vocab = set()
        
        for review in training_data["text"]:
            for word in review.split(" "):
                vocab.add(word)
                
        self.vocab = list(vocab)
        
        
            
    def update_input_layer(self, text):
        global vocab_vector

        # clear out previous state, reset the vector to be all 0s
        self.vocab_vector *= 0
        for word in text.split(" "):
            self.vocab_vector[0][word_column_dict[word]] += 1

# %%
nn = SpamClassificationNeuralNetwork(training_data, num_epochs = 10, learning_rate=0.01)

# %%
nn.train()
# Out:
# Epoch: 0 Progress: 99.9 % Speed(samples/sec): 1114. #Correct: 3219 #Trained: 4572 Training Accuracy: 70.4%
# Epoch: 1 Progress: 99.9 % Speed(samples/sec): 1170. #Correct: 3846 #Trained: 4572 Training Accuracy: 84.1%
# Epoch: 2 Progress: 99.9 % Speed(samples/sec): 1304. #Correct: 4026 #Trained: 4572 Training Accuracy: 88.0%
# Epoch: 3 Progress: 99.9 % Speed(samples/sec): 1385. #Correct: 4120 #Trained: 4572 Training Accuracy: 90.1%
# Epoch: 4 Progress: 99.9 % Speed(samples/sec): 1383. #Correct: 4200 #Trained: 4572 Training Accuracy: 91.8%
# Epoch: 5 Progress: 99.9 % Speed(samples/sec): 1234. #Correct: 4260 #Trained: 4572 Training Accuracy: 93.1%
# Epoch: 6 Progress: 99.9 % Speed(samples/sec): 1215. #Correct: 4294 #Trained: 4572 Training Accuracy: 93.9%
# Epoch: 7 Progress: 99.9 % Speed(samples/sec): 1356. #Correct: 4328 #Trained: 4572 Training Accuracy: 94.6%
# Epoch: 8 Progress: 99.9 % Speed(samples/sec): 1373. #Correct: 4364 #Trained: 4572 Training Accuracy: 95.4%
# Epoch: 9 Progress: 99.9 % Speed(samples/sec): 1359. #Correct: 4389 #Trained: 4572 Training Accuracy: 95.9%
